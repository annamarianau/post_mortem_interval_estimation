# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', 700)

# %% [markdown]
# This notebook creates a kind of "master" dataset containing all available image attributes potentially required for downstream tasks, such as PMI estimation. Available image attributes:
# - anatomic data (i.e., true or predicted bodypart)
# - donor demographic data
# - decay data (i.e, true or predicted SOD)
#
# Since a valid PMI needs to exist, the dataset cohort will consist of donors that have a valid PMI. This data can be found here: '../data/img_PMIs_no_negs.csv'. This will be the "base" dataset from which the "master" dataset will be created.
#
# Outputs:
# - base_df7: final "master" dataset containing all image attributes. This dataset can be found at ../data/master_dataset.pkl and ../data/master_dataset.csv.

# %% [markdown]
# # Import base dataset
# The base dataset consists of all images with a valid PMI.

# %%
base_df = pd.read_csv('../data/img_PMIs_no_negs.csv', usecols=['new_id', 'old_id', 'new_path', 'new_img', 'old_date',
                                                               'date_placed_ARF', 'img_pmi_days'])
base_df.rename(columns={"new_img": "img", "new_path": "img_path", "old_date": "correct_img_date",
                       "img_pmi_days": "PMI_days"}, inplace=True)
base_df = base_df.loc[:,['new_id', 'old_id', 'img_path', 'img', 'correct_img_date', 
                         'date_placed_ARF', 'PMI_days']].copy()
display(base_df.head())
display(base_df.info())
print(base_df.shape)
# Out:
#   new_id    old_id  \
# 0    000  UT01-18D
# 1    000  UT01-18D
# 2    000  UT01-18D
# 3    000  UT01-18D
# 4    000  UT01-18D
#
#                                                              img_path  \
# 0  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.01.JPG
# 1  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.02.JPG
# 2  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.03.JPG
# 3  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.04.JPG
# 4  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.05.JPG
#
#                img correct_img_date date_placed_ARF  PMI_days
# 0  00000121.01.JPG       2018-01-21      2018-01-21       0.0
# 1  00000121.02.JPG       2018-01-21      2018-01-21       0.0
# 2  00000121.03.JPG       2018-01-21      2018-01-21       0.0
# 3  00000121.04.JPG       2018-01-21      2018-01-21       0.0
# 4  00000121.05.JPG       2018-01-21      2018-01-21       0.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1132970 entries, 0 to 1132969
# Data columns (total 7 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   new_id            1132970 non-null  object
#  1   old_id            1132970 non-null  object
#  2   img_path          1132970 non-null  object
#  3   img               1132970 non-null  object
#  4   correct_img_date  1132970 non-null  object
#  5   date_placed_ARF   1132970 non-null  object
#  6   PMI_days          1132970 non-null  float64
# dtypes: float64(1), object(6)
# memory usage: 60.5+ MB
# None
# (1132970, 7)

# %%
# make sure images are unique
base_df.img.nunique()
# Out:
# 1132970

# %% [markdown]
# # Add demographic data

# %%
# import previously processed demography data
demogr_df = pd.read_pickle('/da1_data/icputrd/arf/mean.js/public/anau_demography/demography_processed_new.pkl')
demogr_df.rename(columns={"UTID": "old_id"}, inplace=True)
display(demogr_df.head())
display(demogr_df.info())
print(demogr_df.shape)
# Out:
#      old_id  year  age_at_death   race     sex  autopsy  est_weight_lb  \
# 0  UT81-11D  2011          73.0  white    Male    False          215.0
# 1  UT80-11D  2011          71.0  white    Male    False          170.0
# 2  UT54-11D  2011          49.0  white    Male    False          200.0
# 3  UT82-11D  2011          84.0  white  Female    False          130.0
# 4  UT29-11D  2011          50.0  white    Male    False          194.0
#
#    est_weight_kg  est_stature_in  est_stature_cm  cadaver_stature_cm  \
# 0      97.505669            66.0          167.64               162.5
# 1      77.097506            68.0          172.72               166.0
# 2      90.702948            69.0          175.26               170.0
# 3      58.956916            62.0          157.48               160.0
# 4      87.981859             NaN             NaN               182.0
#
#    cadaver_weight_lbs date_placed_ARF_freezer date_placed_ARF
# 0                 NaN                     NaT             NaT
# 1                 NaN                     NaT      2012-01-09
# 2                 NaN                     NaT             NaT
# 3                 NaN                     NaT      2011-09-23
# 4                 NaN                     NaT             NaT
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1069 entries, 0 to 1068
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   old_id                   1069 non-null   object
#  1   year                     1069 non-null   int64
#  2   age_at_death             938 non-null    float64
#  3   race                     1063 non-null   object
#  4   sex                      1067 non-null   object
#  5   autopsy                  1069 non-null   bool
#  6   est_weight_lb            982 non-null    float64
#  7   est_weight_kg            981 non-null    float64
#  8   est_stature_in           991 non-null    float64
#  9   est_stature_cm           991 non-null    float64
#  10  cadaver_stature_cm       961 non-null    float64
#  11  cadaver_weight_lbs       950 non-null    float64
#  12  date_placed_ARF_freezer  307 non-null    datetime64[ns]
#  13  date_placed_ARF          876 non-null    datetime64[ns]
# dtypes: bool(1), datetime64[ns](2), float64(7), int64(1), object(3)
# memory usage: 109.7+ KB
# None
# (1069, 14)

# %%
# drop date_placed_ARF column
demogr_df.drop('date_placed_ARF', axis=1, inplace=True)

# %%
# make sure old_id are unique
demogr_df.old_id.nunique()
# Out:
# 1069

# %%
# left join base_df with demogr_df
base_df2 = pd.merge(base_df, demogr_df, how='left', on='old_id')
display(base_df2.head())
display(base_df2.info())
print(base_df2.shape)
del demogr_df
# Out:
#   new_id    old_id  \
# 0    000  UT01-18D
# 1    000  UT01-18D
# 2    000  UT01-18D
# 3    000  UT01-18D
# 4    000  UT01-18D
#
#                                                              img_path  \
# 0  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.01.JPG
# 1  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.02.JPG
# 2  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.03.JPG
# 3  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.04.JPG
# 4  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.05.JPG
#
#                img correct_img_date date_placed_ARF  PMI_days  year  \
# 0  00000121.01.JPG       2018-01-21      2018-01-21       0.0  2018
# 1  00000121.02.JPG       2018-01-21      2018-01-21       0.0  2018
# 2  00000121.03.JPG       2018-01-21      2018-01-21       0.0  2018
# 3  00000121.04.JPG       2018-01-21      2018-01-21       0.0  2018
# 4  00000121.05.JPG       2018-01-21      2018-01-21       0.0  2018
#
#    age_at_death   race   sex  autopsy  est_weight_lb  est_weight_kg  \
# 0          73.0  white  Male    False          160.0      72.562358
# 1          73.0  white  Male    False          160.0      72.562358
# 2          73.0  white  Male    False          160.0      72.562358
# 3          73.0  white  Male    False          160.0      72.562358
# 4          73.0  white  Male    False          160.0      72.562358
#
#    est_stature_in  est_stature_cm  cadaver_stature_cm  cadaver_weight_lbs  \
# 0            70.0           177.8               169.0               150.0
# 1            70.0           177.8               169.0               150.0
# 2            70.0           177.8               169.0               150.0
# 3            70.0           177.8               169.0               150.0
# 4            70.0           177.8               169.0               150.0
#
#   date_placed_ARF_freezer
# 0              2018-01-04
# 1              2018-01-04
# 2              2018-01-04
# 3              2018-01-04
# 4              2018-01-04
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1132970 entries, 0 to 1132969
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   new_id                   1132970 non-null  object
#  1   old_id                   1132970 non-null  object
#  2   img_path                 1132970 non-null  object
#  3   img                      1132970 non-null  object
#  4   correct_img_date         1132970 non-null  object
#  5   date_placed_ARF          1132970 non-null  object
#  6   PMI_days                 1132970 non-null  float64
#  7   year                     1132970 non-null  int64
#  8   age_at_death             1124770 non-null  float64
#  9   race                     1132348 non-null  object
#  10  sex                      1132630 non-null  object
#  11  autopsy                  1132970 non-null  bool
#  12  est_weight_lb            1056421 non-null  float64
#  13  est_weight_kg            1056219 non-null  float64
#  14  est_stature_in           1068494 non-null  float64
#  15  est_stature_cm           1068494 non-null  float64
#  16  cadaver_stature_cm       993005 non-null   float64
#  17  cadaver_weight_lbs       1103693 non-null  float64
#  18  date_placed_ARF_freezer  199868 non-null   datetime64[ns]
# dtypes: bool(1), datetime64[ns](1), float64(8), int64(1), object(8)
# memory usage: 165.3+ MB
# None
# (1132970, 19)

# %% [markdown]
# # Add anatomic data

# %% [markdown]
# ### True anatomic data

# %%
# import true anatomic data (clusters_w_stakes MongoDB collection)
true_anatomic_df = pd.read_csv('/da1_data/icputrd/decaying_human_body_part_classifier/from_anau/data/all_labeled_img.txt',
                              header=None, names=['img_path', 'true_BP'])
display(true_anatomic_df.head())
display(true_anatomic_df.info())
print(true_anatomic_df.shape)
print(true_anatomic_df.img_path.nunique())
# Out:
#                          img_path true_BP
# 0  /anau_img3/00b/00b00312.22.JPG     arm
# 1  /anau_img3/00b/00b00310.26.JPG    foot
# 2  /anau_img3/00b/00b00311.19.JPG     arm
# 3  /anau_img3/00b/00b00320.23.JPG    hips
# 4  /anau_img3/00b/00b00312.27.JPG    foot
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76948 entries, 0 to 76947
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   img_path  76948 non-null  object
#  1   true_BP   76948 non-null  object
# dtypes: object(2)
# memory usage: 1.2+ MB
# None
# (76948, 2)
# 76948

# %%
# create image column from img_path column
true_anatomic_df['img'] = true_anatomic_df.img_path.str.split('/', expand=True)[3]
display(true_anatomic_df.head())
# Out:
#                          img_path true_BP              img
# 0  /anau_img3/00b/00b00312.22.JPG     arm  00b00312.22.JPG
# 1  /anau_img3/00b/00b00310.26.JPG    foot  00b00310.26.JPG
# 2  /anau_img3/00b/00b00311.19.JPG     arm  00b00311.19.JPG
# 3  /anau_img3/00b/00b00320.23.JPG    hips  00b00320.23.JPG
# 4  /anau_img3/00b/00b00312.27.JPG    foot  00b00312.27.JPG

# %%
# left join base_df2 with true_anatomic_df
base_df3 = pd.merge(base_df2, true_anatomic_df[['img', 'true_BP']], how='left', on='img')
display(base_df3.head())
display(base_df3.info())
print(base_df3.shape)
del true_anatomic_df
# Out:
#   new_id    old_id  \
# 0    000  UT01-18D
# 1    000  UT01-18D
# 2    000  UT01-18D
# 3    000  UT01-18D
# 4    000  UT01-18D
#
#                                                              img_path  \
# 0  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.01.JPG
# 1  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.02.JPG
# 2  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.03.JPG
# 3  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.04.JPG
# 4  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.05.JPG
#
#                img correct_img_date date_placed_ARF  PMI_days  year  \
# 0  00000121.01.JPG       2018-01-21      2018-01-21       0.0  2018
# 1  00000121.02.JPG       2018-01-21      2018-01-21       0.0  2018
# 2  00000121.03.JPG       2018-01-21      2018-01-21       0.0  2018
# 3  00000121.04.JPG       2018-01-21      2018-01-21       0.0  2018
# 4  00000121.05.JPG       2018-01-21      2018-01-21       0.0  2018
#
#    age_at_death   race   sex  autopsy  est_weight_lb  est_weight_kg  \
# 0          73.0  white  Male    False          160.0      72.562358
# 1          73.0  white  Male    False          160.0      72.562358
# 2          73.0  white  Male    False          160.0      72.562358
# 3          73.0  white  Male    False          160.0      72.562358
# 4          73.0  white  Male    False          160.0      72.562358
#
#    est_stature_in  est_stature_cm  cadaver_stature_cm  cadaver_weight_lbs  \
# 0            70.0           177.8               169.0               150.0
# 1            70.0           177.8               169.0               150.0
# 2            70.0           177.8               169.0               150.0
# 3            70.0           177.8               169.0               150.0
# 4            70.0           177.8               169.0               150.0
#
#   date_placed_ARF_freezer true_BP
# 0              2018-01-04     NaN
# 1              2018-01-04     NaN
# 2              2018-01-04     NaN
# 3              2018-01-04     NaN
# 4              2018-01-04     NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1132970 entries, 0 to 1132969
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   new_id                   1132970 non-null  object
#  1   old_id                   1132970 non-null  object
#  2   img_path                 1132970 non-null  object
#  3   img                      1132970 non-null  object
#  4   correct_img_date         1132970 non-null  object
#  5   date_placed_ARF          1132970 non-null  object
#  6   PMI_days                 1132970 non-null  float64
#  7   year                     1132970 non-null  int64
#  8   age_at_death             1124770 non-null  float64
#  9   race                     1132348 non-null  object
#  10  sex                      1132630 non-null  object
#  11  autopsy                  1132970 non-null  bool
#  12  est_weight_lb            1056421 non-null  float64
#  13  est_weight_kg            1056219 non-null  float64
#  14  est_stature_in           1068494 non-null  float64
#  15  est_stature_cm           1068494 non-null  float64
#  16  cadaver_stature_cm       993005 non-null   float64
#  17  cadaver_weight_lbs       1103693 non-null  float64
#  18  date_placed_ARF_freezer  199868 non-null   datetime64[ns]
#  19  true_BP                  45930 non-null    object
# dtypes: bool(1), datetime64[ns](1), float64(8), int64(1), object(9)
# memory usage: 174.0+ MB
# None
# (1132970, 20)

# %% [markdown]
# ### Predicted anatomic data

# %%
# import predicted anatomic data 
pred_anatomic_df = pd.read_csv('/da1_data/icputrd/decaying_human_body_part_classifier/from_anau/ex1_preds', 
                               delimiter= ':', header=None, names=['img_path', 'pred_BP', 'pred_conf'])
pred_anatomic_df.rename(columns={"pred_conf": "pred_BP_conf"}, inplace=True)
display(pred_anatomic_df.head())
display(pred_anatomic_df.info())
print(pred_anatomic_df.shape)
print(pred_anatomic_df.img_path.nunique())
# Out:
#                                                              img_path  \
# 0  /da1_data/icputrd/arf/mean.js/public/anau_img3/88a/88a00106.10.JPG
# 1  /da1_data/icputrd/arf/mean.js/public/anau_img3/88a/88a00106.01.JPG
# 2  /da1_data/icputrd/arf/mean.js/public/anau_img3/88a/88a00106.02.JPG
# 3  /da1_data/icputrd/arf/mean.js/public/anau_img3/88a/88a00106.03.JPG
# 4  /da1_data/icputrd/arf/mean.js/public/anau_img3/88a/88a00106.04.JPG
#
#     pred_BP  pred_BP_conf
# 0      legs         99.99
# 1     stake         99.99
# 2     stake         99.99
# 3  fullbody         99.63
# 4     torso        100.00
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1376574 entries, 0 to 1376573
# Data columns (total 3 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   img_path      1376574 non-null  object
#  1   pred_BP       1376574 non-null  object
#  2   pred_BP_conf  1376574 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 31.5+ MB
# None
# (1376574, 3)
# 1376574

# %%
# create image column from img_path column
pred_anatomic_df['img'] = pred_anatomic_df.img_path.str.split('/', expand=True)[8]
display(pred_anatomic_df.head())
# Out:
#                                                              img_path  \
# 0  /da1_data/icputrd/arf/mean.js/public/anau_img3/88a/88a00106.10.JPG
# 1  /da1_data/icputrd/arf/mean.js/public/anau_img3/88a/88a00106.01.JPG
# 2  /da1_data/icputrd/arf/mean.js/public/anau_img3/88a/88a00106.02.JPG
# 3  /da1_data/icputrd/arf/mean.js/public/anau_img3/88a/88a00106.03.JPG
# 4  /da1_data/icputrd/arf/mean.js/public/anau_img3/88a/88a00106.04.JPG
#
#     pred_BP  pred_BP_conf              img
# 0      legs         99.99  88a00106.10.JPG
# 1     stake         99.99  88a00106.01.JPG
# 2     stake         99.99  88a00106.02.JPG
# 3  fullbody         99.63  88a00106.03.JPG
# 4     torso        100.00  88a00106.04.JPG

# %%
# left join base_df3 with pred_anatomic_df
base_df4 = pd.merge(base_df3, pred_anatomic_df[['img', 'pred_BP', 'pred_BP_conf']], how='left', on='img')
display(base_df4.head())
display(base_df4.info())
print(base_df4.shape)
del pred_anatomic_df
# Out:
#   new_id    old_id  \
# 0    000  UT01-18D
# 1    000  UT01-18D
# 2    000  UT01-18D
# 3    000  UT01-18D
# 4    000  UT01-18D
#
#                                                              img_path  \
# 0  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.01.JPG
# 1  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.02.JPG
# 2  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.03.JPG
# 3  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.04.JPG
# 4  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.05.JPG
#
#                img correct_img_date date_placed_ARF  PMI_days  year  \
# 0  00000121.01.JPG       2018-01-21      2018-01-21       0.0  2018
# 1  00000121.02.JPG       2018-01-21      2018-01-21       0.0  2018
# 2  00000121.03.JPG       2018-01-21      2018-01-21       0.0  2018
# 3  00000121.04.JPG       2018-01-21      2018-01-21       0.0  2018
# 4  00000121.05.JPG       2018-01-21      2018-01-21       0.0  2018
#
#    age_at_death   race   sex  autopsy  est_weight_lb  est_weight_kg  \
# 0          73.0  white  Male    False          160.0      72.562358
# 1          73.0  white  Male    False          160.0      72.562358
# 2          73.0  white  Male    False          160.0      72.562358
# 3          73.0  white  Male    False          160.0      72.562358
# 4          73.0  white  Male    False          160.0      72.562358
#
#    est_stature_in  est_stature_cm  cadaver_stature_cm  cadaver_weight_lbs  \
# 0            70.0           177.8               169.0               150.0
# 1            70.0           177.8               169.0               150.0
# 2            70.0           177.8               169.0               150.0
# 3            70.0           177.8               169.0               150.0
# 4            70.0           177.8               169.0               150.0
#
#   date_placed_ARF_freezer true_BP   pred_BP  pred_BP_conf
# 0              2018-01-04     NaN     stake        100.00
# 1              2018-01-04     NaN  fullbody         85.51
# 2              2018-01-04     NaN  fullbody         90.52
# 3              2018-01-04     NaN  fullbody         99.50
# 4              2018-01-04     NaN  fullbody         43.47
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1132970 entries, 0 to 1132969
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   new_id                   1132970 non-null  object
#  1   old_id                   1132970 non-null  object
#  2   img_path                 1132970 non-null  object
#  3   img                      1132970 non-null  object
#  4   correct_img_date         1132970 non-null  object
#  5   date_placed_ARF          1132970 non-null  object
#  6   PMI_days                 1132970 non-null  float64
#  7   year                     1132970 non-null  int64
#  8   age_at_death             1124770 non-null  float64
#  9   race                     1132348 non-null  object
#  10  sex                      1132630 non-null  object
#  11  autopsy                  1132970 non-null  bool
#  12  est_weight_lb            1056421 non-null  float64
#  13  est_weight_kg            1056219 non-null  float64
#  14  est_stature_in           1068494 non-null  float64
#  15  est_stature_cm           1068494 non-null  float64
#  16  cadaver_stature_cm       993005 non-null   float64
#  17  cadaver_weight_lbs       1103693 non-null  float64
#  18  date_placed_ARF_freezer  199868 non-null   datetime64[ns]
#  19  true_BP                  45930 non-null    object
#  20  pred_BP                  1132692 non-null  object
#  21  pred_BP_conf             1132692 non-null  float64
# dtypes: bool(1), datetime64[ns](1), float64(9), int64(1), object(10)
# memory usage: 191.2+ MB
# None
# (1132970, 22)

# %% [markdown]
# # Add SOD data
# This can be from the Gelderman or Megyesi scoring methods.

# %% [markdown]
# ### True SOD Gelderman data
# Data that was labeled using Gelderman's SOD scoring method.

# %%
# import true SOD Gelderman data
files_ls = ['head_labeled', 'torso_labeled', 'limbs_labeled']
true_sod_df = pd.concat((pd.read_csv('/home/anau/SOD_labeling/Gelderman/from_preds/'+f, usecols=[0,1,2],
                                    names=['img_path', 'true_SOD_G', 'BP_of_true_SOD_G']) for f in files_ls))

display(true_sod_df.head())
display(true_sod_df.info())
print(true_sod_df.shape)
print(true_sod_df.img_path.nunique())
# Out:
#                               img_path true_SOD_G BP_of_true_SOD_G
# 0  /anau_img3/abd/abd00928.20.icon.JPG        h-4             head
# 1  /anau_img3/abd/abd00928.07.icon.JPG        h-4             head
# 2  /anau_img3/abd/abd00928.08.icon.JPG        h-4             head
# 3  /anau_img3/dcd/dcd10203.30.icon.JPG        h-4             head
# 4  /anau_img3/dcd/dcd10203.31.icon.JPG        h-4             head
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6055 entries, 0 to 2031
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   img_path          6055 non-null   object
#  1   true_SOD_G        6055 non-null   object
#  2   BP_of_true_SOD_G  6055 non-null   object
# dtypes: object(3)
# memory usage: 189.2+ KB
# None
# (6055, 3)
# 6055

# %%
# create image column from img_path column
true_sod_df['img'] = true_sod_df.img_path.str.split('/', expand=True)[3]
true_sod_df['img'] = true_sod_df['img'].str.replace('.icon','')
display(true_sod_df.head())
# Out:
# <ipython-input-56-6f515cf2cf19>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   true_sod_df['img'] = true_sod_df['img'].str.replace('.icon','')
#                               img_path true_SOD_G BP_of_true_SOD_G  \
# 0  /anau_img3/abd/abd00928.20.icon.JPG        h-4             head
# 1  /anau_img3/abd/abd00928.07.icon.JPG        h-4             head
# 2  /anau_img3/abd/abd00928.08.icon.JPG        h-4             head
# 3  /anau_img3/dcd/dcd10203.30.icon.JPG        h-4             head
# 4  /anau_img3/dcd/dcd10203.31.icon.JPG        h-4             head
#
#                img
# 0  abd00928.20.JPG
# 1  abd00928.07.JPG
# 2  abd00928.08.JPG
# 3  dcd10203.30.JPG
# 4  dcd10203.31.JPG

# %%
# left join base_df4 with true_sod_df
base_df5 = pd.merge(base_df4, true_sod_df[['img', 'true_SOD_G', 'BP_of_true_SOD_G']], how='left', on='img')
display(base_df5.head())
display(base_df5.info())
print(base_df5.shape)
del true_sod_df
# Out:
#   new_id    old_id  \
# 0    000  UT01-18D
# 1    000  UT01-18D
# 2    000  UT01-18D
# 3    000  UT01-18D
# 4    000  UT01-18D
#
#                                                              img_path  \
# 0  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.01.JPG
# 1  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.02.JPG
# 2  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.03.JPG
# 3  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.04.JPG
# 4  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.05.JPG
#
#                img correct_img_date date_placed_ARF  PMI_days  year  \
# 0  00000121.01.JPG       2018-01-21      2018-01-21       0.0  2018
# 1  00000121.02.JPG       2018-01-21      2018-01-21       0.0  2018
# 2  00000121.03.JPG       2018-01-21      2018-01-21       0.0  2018
# 3  00000121.04.JPG       2018-01-21      2018-01-21       0.0  2018
# 4  00000121.05.JPG       2018-01-21      2018-01-21       0.0  2018
#
#    age_at_death   race   sex  autopsy  est_weight_lb  est_weight_kg  \
# 0          73.0  white  Male    False          160.0      72.562358
# 1          73.0  white  Male    False          160.0      72.562358
# 2          73.0  white  Male    False          160.0      72.562358
# 3          73.0  white  Male    False          160.0      72.562358
# 4          73.0  white  Male    False          160.0      72.562358
#
#    est_stature_in  est_stature_cm  cadaver_stature_cm  cadaver_weight_lbs  \
# 0            70.0           177.8               169.0               150.0
# 1            70.0           177.8               169.0               150.0
# 2            70.0           177.8               169.0               150.0
# 3            70.0           177.8               169.0               150.0
# 4            70.0           177.8               169.0               150.0
#
#   date_placed_ARF_freezer true_BP   pred_BP  pred_BP_conf true_SOD_G  \
# 0              2018-01-04     NaN     stake        100.00        NaN
# 1              2018-01-04     NaN  fullbody         85.51        NaN
# 2              2018-01-04     NaN  fullbody         90.52        NaN
# 3              2018-01-04     NaN  fullbody         99.50        NaN
# 4              2018-01-04     NaN  fullbody         43.47        NaN
#
#   BP_of_true_SOD_G
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1132970 entries, 0 to 1132969
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   new_id                   1132970 non-null  object
#  1   old_id                   1132970 non-null  object
#  2   img_path                 1132970 non-null  object
#  3   img                      1132970 non-null  object
#  4   correct_img_date         1132970 non-null  object
#  5   date_placed_ARF          1132970 non-null  object
#  6   PMI_days                 1132970 non-null  float64
#  7   year                     1132970 non-null  int64
#  8   age_at_death             1124770 non-null  float64
#  9   race                     1132348 non-null  object
#  10  sex                      1132630 non-null  object
#  11  autopsy                  1132970 non-null  bool
#  12  est_weight_lb            1056421 non-null  float64
#  13  est_weight_kg            1056219 non-null  float64
#  14  est_stature_in           1068494 non-null  float64
#  15  est_stature_cm           1068494 non-null  float64
#  16  cadaver_stature_cm       993005 non-null   float64
#  17  cadaver_weight_lbs       1103693 non-null  float64
#  18  date_placed_ARF_freezer  199868 non-null   datetime64[ns]
#  19  true_BP                  45930 non-null    object
#  20  pred_BP                  1132692 non-null  object
#  21  pred_BP_conf             1132692 non-null  float64
#  22  true_SOD_G               6055 non-null     object
#  23  BP_of_true_SOD_G         6055 non-null     object
# dtypes: bool(1), datetime64[ns](1), float64(9), int64(1), object(12)
# memory usage: 208.5+ MB
# None
# (1132970, 24)

# %% [markdown]
# ### Predicted SOD Gelderman data
# Data that was labeled with AI trained on Gelderman's SOD data.

# %%
# import predicted SOD data
files_ls = ['head_clusters_preds', 'torso_clusters_preds', 'limbs_clusters_preds']
pred_sod_df = pd.concat((pd.read_csv('/home/anau/SOD_labeling/Gelderman/from_preds/predict/'+f) for f in files_ls))
pred_sod_df.rename(columns={"img": "img_path", "pred": "pred_SOD_G_conf", "k=1": "pred_SOD_G"}, inplace=True)
pred_sod_df = pred_sod_df.loc[:,['img_path', 'pred_SOD_G', 'pred_SOD_G_conf']].copy()
display(pred_sod_df.head())
display(pred_sod_df.info())
print(pred_sod_df.shape)
print(pred_sod_df.img_path.nunique())
# Out:
#                                                             img_path  \
# 0  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00323.18.JPG
# 1  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00324.19.JPG
# 2  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00326.19.JPG
# 3  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00327.19.JPG
# 4  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00329.23.JPG
#
#    pred_SOD_G  \
# 0           3
# 1           3
# 2           3
# 3           3
# 4           3
#
#                                                                                                                               pred_SOD_G_conf
# 0  [1.8596528830738812e-11, 1.0770167136797681e-05, 0.9999768733978271, 1.2416985555319116e-05, 6.144854625134144e-10, 1.945529071178953e-09]
# 1    [2.7908717004088146e-12, 9.229962074641662e-07, 0.999977707862854, 2.1307549104676582e-05, 7.363529785919809e-10, 3.004331505795932e-10]
# 2   [1.9816505381076155e-10, 2.2630556486546993e-06, 0.9999904632568359, 7.294603165064473e-06, 1.6762526922065035e-09, 6.09018738217948e-11]
# 3   [4.763862568313293e-11, 6.425679657695582e-06, 0.9992665648460388, 0.0007268352201208472, 1.2655030445785087e-07, 1.2454775877301927e-08]
# 4  [1.8943072110921833e-10, 1.5520903616561554e-05, 0.9999841451644897, 3.515644380058802e-07, 1.3943256271797821e-10, 6.341189379144296e-11]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32378 entries, 0 to 18265
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   img_path         32378 non-null  object
#  1   pred_SOD_G       32378 non-null  int64
#  2   pred_SOD_G_conf  32378 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1011.8+ KB
# None
# (32378, 3)
# 32378

# %%
# create image column from img_path column
pred_sod_df['img'] = pred_sod_df.img_path.str.split('/', expand=True)[8]
display(pred_sod_df.head())
# Out:
#                                                             img_path  \
# 0  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00323.18.JPG
# 1  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00324.19.JPG
# 2  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00326.19.JPG
# 3  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00327.19.JPG
# 4  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00329.23.JPG
#
#    pred_SOD_G  \
# 0           3
# 1           3
# 2           3
# 3           3
# 4           3
#
#                                                                                                                               pred_SOD_G_conf  \
# 0  [1.8596528830738812e-11, 1.0770167136797681e-05, 0.9999768733978271, 1.2416985555319116e-05, 6.144854625134144e-10, 1.945529071178953e-09]
# 1    [2.7908717004088146e-12, 9.229962074641662e-07, 0.999977707862854, 2.1307549104676582e-05, 7.363529785919809e-10, 3.004331505795932e-10]
# 2   [1.9816505381076155e-10, 2.2630556486546993e-06, 0.9999904632568359, 7.294603165064473e-06, 1.6762526922065035e-09, 6.09018738217948e-11]
# 3   [4.763862568313293e-11, 6.425679657695582e-06, 0.9992665648460388, 0.0007268352201208472, 1.2655030445785087e-07, 1.2454775877301927e-08]
# 4  [1.8943072110921833e-10, 1.5520903616561554e-05, 0.9999841451644897, 3.515644380058802e-07, 1.3943256271797821e-10, 6.341189379144296e-11]
#
#                img
# 0  00b00323.18.JPG
# 1  00b00324.19.JPG
# 2  00b00326.19.JPG
# 3  00b00327.19.JPG
# 4  00b00329.23.JPG

# %%
# extract highest confidence from pred_SOD_G_conf and save as new column
def modify_dtype(row):
    row = [float(x) for x in row] 
    max_prob = max(row)
    return max_prob

pred_sod_df['pred_SOD_G_conf_new'] = pred_sod_df.pred_SOD_G_conf.apply(lambda x: x.strip('[]').split(','))
pred_sod_df['pred_SOD_G_conf_new'] = pred_sod_df.pred_SOD_G_conf_new.apply(modify_dtype)
display(pred_sod_df.head(10))
pred_sod_df.drop(['pred_SOD_G_conf'], axis=1, inplace=True)
pred_sod_df.rename(columns={"pred_SOD_G_conf_new": "pred_SOD_G_conf"}, inplace=True)
pred_sod_df = pred_sod_df.loc[:,['img_path', 'img', 'pred_SOD_G', 'pred_SOD_G_conf']].copy()
display(pred_sod_df.head(10))
# Out:
#                                                             img_path  \
# 0  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00323.18.JPG
# 1  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00324.19.JPG
# 2  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00326.19.JPG
# 3  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00327.19.JPG
# 4  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00329.23.JPG
# 5  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00331.25.JPG
# 6  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00330.11.JPG
# 7  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00401.25.JPG
# 8  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00331.12.JPG
# 9  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00425.22.JPG
#
#    pred_SOD_G  \
# 0           3
# 1           3
# 2           3
# 3           3
# 4           3
# 5           3
# 6           3
# 7           3
# 8           3
# 9           3
#
#                                                                                                                               pred_SOD_G_conf  \
# 0  [1.8596528830738812e-11, 1.0770167136797681e-05, 0.9999768733978271, 1.2416985555319116e-05, 6.144854625134144e-10, 1.945529071178953e-09]
# 1    [2.7908717004088146e-12, 9.229962074641662e-07, 0.999977707862854, 2.1307549104676582e-05, 7.363529785919809e-10, 3.004331505795932e-10]
# 2   [1.9816505381076155e-10, 2.2630556486546993e-06, 0.9999904632568359, 7.294603165064473e-06, 1.6762526922065035e-09, 6.09018738217948e-11]
# 3   [4.763862568313293e-11, 6.425679657695582e-06, 0.9992665648460388, 0.0007268352201208472, 1.2655030445785087e-07, 1.2454775877301927e-08]
# 4  [1.8943072110921833e-10, 1.5520903616561554e-05, 0.9999841451644897, 3.515644380058802e-07, 1.3943256271797821e-10, 6.341189379144296e-11]
# 5     [7.235614885026109e-12, 1.937119691319822e-07, 0.9999927282333374, 7.00877399140154e-06, 8.420728558888868e-10, 2.1879263678581395e-10]
# 6   [4.102733430766392e-11, 6.931198015536211e-08, 0.9999673366546631, 3.255257252021693e-05, 2.6792886131943305e-08, 4.1194665734156644e-11]
# 7    [2.908651985933375e-09, 1.8822316860678256e-06, 0.9998575448989868, 0.0001399808970745653, 5.377323191169125e-07, 2.710314994658347e-08]
# 8      [5.96862337332027e-09, 6.183307505125413e-06, 0.9991486072540283, 0.0008440593373961747, 6.347546559481998e-07, 4.337266261700279e-07]
# 9   [6.315889322650037e-07, 2.1791613562527345e-06, 0.9972829818725586, 0.00023548606259282678, 0.0024752113968133926, 3.446732534939656e-06]
#
#                img  pred_SOD_G_conf_new
# 0  00b00323.18.JPG             0.999977
# 1  00b00324.19.JPG             0.999978
# 2  00b00326.19.JPG             0.999990
# 3  00b00327.19.JPG             0.999267
# 4  00b00329.23.JPG             0.999984
# 5  00b00331.25.JPG             0.999993
# 6  00b00330.11.JPG             0.999967
# 7  00b00401.25.JPG             0.999858
# 8  00b00331.12.JPG             0.999149
# 9  00b00425.22.JPG             0.997283
#                                                             img_path  \
# 0  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00323.18.JPG
# 1  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00324.19.JPG
# 2  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00326.19.JPG
# 3  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00327.19.JPG
# 4  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00329.23.JPG
# 5  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00331.25.JPG
# 6  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00330.11.JPG
# 7  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00401.25.JPG
# 8  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00331.12.JPG
# 9  /da1_data/icputrd/arf/mean.js/public/sara_img/00b/00b00425.22.JPG
#
#                img  pred_SOD_G  pred_SOD_G_conf
# 0  00b00323.18.JPG           3         0.999977
# 1  00b00324.19.JPG           3         0.999978
# 2  00b00326.19.JPG           3         0.999990
# 3  00b00327.19.JPG           3         0.999267
# 4  00b00329.23.JPG           3         0.999984
# 5  00b00331.25.JPG           3         0.999993
# 6  00b00330.11.JPG           3         0.999967
# 7  00b00401.25.JPG           3         0.999858
# 8  00b00331.12.JPG           3         0.999149
# 9  00b00425.22.JPG           3         0.997283

# %%
# left join base_df5 with pred_sod_df
base_df6 = pd.merge(base_df5, pred_sod_df[['img', 'pred_SOD_G', 'pred_SOD_G_conf']], how='left', on='img')
display(base_df6.head())
display(base_df6.info())
print(base_df6.shape)
del pred_sod_df
# Out:
#   new_id    old_id  \
# 0    000  UT01-18D
# 1    000  UT01-18D
# 2    000  UT01-18D
# 3    000  UT01-18D
# 4    000  UT01-18D
#
#                                                              img_path  \
# 0  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.01.JPG
# 1  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.02.JPG
# 2  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.03.JPG
# 3  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.04.JPG
# 4  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.05.JPG
#
#                img correct_img_date date_placed_ARF  PMI_days  year  \
# 0  00000121.01.JPG       2018-01-21      2018-01-21       0.0  2018
# 1  00000121.02.JPG       2018-01-21      2018-01-21       0.0  2018
# 2  00000121.03.JPG       2018-01-21      2018-01-21       0.0  2018
# 3  00000121.04.JPG       2018-01-21      2018-01-21       0.0  2018
# 4  00000121.05.JPG       2018-01-21      2018-01-21       0.0  2018
#
#    age_at_death   race   sex  autopsy  est_weight_lb  est_weight_kg  \
# 0          73.0  white  Male    False          160.0      72.562358
# 1          73.0  white  Male    False          160.0      72.562358
# 2          73.0  white  Male    False          160.0      72.562358
# 3          73.0  white  Male    False          160.0      72.562358
# 4          73.0  white  Male    False          160.0      72.562358
#
#    est_stature_in  est_stature_cm  cadaver_stature_cm  cadaver_weight_lbs  \
# 0            70.0           177.8               169.0               150.0
# 1            70.0           177.8               169.0               150.0
# 2            70.0           177.8               169.0               150.0
# 3            70.0           177.8               169.0               150.0
# 4            70.0           177.8               169.0               150.0
#
#   date_placed_ARF_freezer true_BP   pred_BP  pred_BP_conf true_SOD_G  \
# 0              2018-01-04     NaN     stake        100.00        NaN
# 1              2018-01-04     NaN  fullbody         85.51        NaN
# 2              2018-01-04     NaN  fullbody         90.52        NaN
# 3              2018-01-04     NaN  fullbody         99.50        NaN
# 4              2018-01-04     NaN  fullbody         43.47        NaN
#
#   BP_of_true_SOD_G  pred_SOD_G  pred_SOD_G_conf
# 0              NaN         NaN              NaN
# 1              NaN         NaN              NaN
# 2              NaN         NaN              NaN
# 3              NaN         NaN              NaN
# 4              NaN         NaN              NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1132970 entries, 0 to 1132969
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   new_id                   1132970 non-null  object
#  1   old_id                   1132970 non-null  object
#  2   img_path                 1132970 non-null  object
#  3   img                      1132970 non-null  object
#  4   correct_img_date         1132970 non-null  object
#  5   date_placed_ARF          1132970 non-null  object
#  6   PMI_days                 1132970 non-null  float64
#  7   year                     1132970 non-null  int64
#  8   age_at_death             1124770 non-null  float64
#  9   race                     1132348 non-null  object
#  10  sex                      1132630 non-null  object
#  11  autopsy                  1132970 non-null  bool
#  12  est_weight_lb            1056421 non-null  float64
#  13  est_weight_kg            1056219 non-null  float64
#  14  est_stature_in           1068494 non-null  float64
#  15  est_stature_cm           1068494 non-null  float64
#  16  cadaver_stature_cm       993005 non-null   float64
#  17  cadaver_weight_lbs       1103693 non-null  float64
#  18  date_placed_ARF_freezer  199868 non-null   datetime64[ns]
#  19  true_BP                  45930 non-null    object
#  20  pred_BP                  1132692 non-null  object
#  21  pred_BP_conf             1132692 non-null  float64
#  22  true_SOD_G               6055 non-null     object
#  23  BP_of_true_SOD_G         6055 non-null     object
#  24  pred_SOD_G               20873 non-null    float64
#  25  pred_SOD_G_conf          20873 non-null    float64
# dtypes: bool(1), datetime64[ns](1), float64(11), int64(1), object(12)
# memory usage: 225.8+ MB
# None
# (1132970, 26)

# %% [markdown]
# ### True SOD Megyesi data
# Data that was labeled using Megyesi's SOD scoring method.

# %%
true_sod_head_df = pd.read_csv('/home/anau/SOD_labeling/Megyesi/head/experiment_5/head_labeled_merged',
                              usecols=[0,1,], names=['img_path', 'true_SOD_M'])
true_sod_head_df['BP_of_true_SOD_M'] = 'head'
display(true_sod_head_df.head())
print(true_sod_head_df.shape)
# Out:
#                               img_path  true_SOD_M BP_of_true_SOD_M
# 0  /anau_img3/4cd/4cd00612.21.icon.JPG           1             head
# 1  /anau_img3/b4b/b4b10107.16.icon.JPG           1             head
# 2  /anau_img3/38e/38e10122.04.icon.JPG           1             head
# 3  /anau_img3/0e4/0e401201.29.icon.JPG           1             head
# 4  /anau_img3/0e4/0e401201.28.icon.JPG           1             head
# (4220, 3)

# %%
true_sod_torso_df = pd.read_csv('/home/anau/SOD_labeling/Megyesi/torso/exp2/torso_labeled',
                              usecols=[0,1,2], names=['img_path', 'true_SOD_M', 'BP_of_true_SOD_M'])
display(true_sod_torso_df.head())
print(true_sod_torso_df.shape)
# Out:
#                              img_path  true_SOD_M BP_of_true_SOD_M
# 0  /sara_img/34d/34d00228.16.icon.JPG           2         backside
# 1  /sara_img/db7/db700607.11.icon.JPG           3            torso
# 2  /sara_img/0db/0db00530.07.icon.JPG           2         backside
# 3  /sara_img/a18/a1800325.07.icon.JPG           2         backside
# 4  /sara_img/2c3/2c310131.18.icon.JPG           3         backside
# (1979, 3)

# %%
true_sod_limbs_df = pd.read_csv('/home/anau/SOD_labeling/Megyesi/limbs/exp1/limbs_labeled',
                              usecols=[0,1,2], names=['img_path', 'true_SOD_M', 'BP_of_true_SOD_M'])
display(true_sod_limbs_df.head())
print(true_sod_limbs_df.shape)
# Out:
#                              img_path  true_SOD_M BP_of_true_SOD_M
# 0  /sara_img/65b/65b01001.35.icon.JPG           1              arm
# 1  /sara_img/35a/35a00330.22.icon.JPG           2              arm
# 2  /sara_img/3de/3de10120.10.icon.JPG           2             legs
# 3  /sara_img/243/24300801.50.icon.JPG           2             legs
# 4  /sara_img/9f4/9f400511.19.icon.JPG           4             legs
# (2152, 3)

# %%
# concat true_sod_head_df, true_sod_torso_df, true_sod_limbs_df
true_sod_df = pd.concat([true_sod_head_df, true_sod_torso_df, true_sod_limbs_df], axis=0)

display(true_sod_df.head())
display(true_sod_df.info())
print(true_sod_df.shape)
print(true_sod_df.img_path.nunique())
# Out:
#                               img_path  true_SOD_M BP_of_true_SOD_M
# 0  /anau_img3/4cd/4cd00612.21.icon.JPG           1             head
# 1  /anau_img3/b4b/b4b10107.16.icon.JPG           1             head
# 2  /anau_img3/38e/38e10122.04.icon.JPG           1             head
# 3  /anau_img3/0e4/0e401201.29.icon.JPG           1             head
# 4  /anau_img3/0e4/0e401201.28.icon.JPG           1             head
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8351 entries, 0 to 2151
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   img_path          8351 non-null   object
#  1   true_SOD_M        8351 non-null   int64
#  2   BP_of_true_SOD_M  8351 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 261.0+ KB
# None
# (8351, 3)
# 8346

# %%
# analyze duplicate images
display(true_sod_df[true_sod_df.duplicated('img_path', keep=False)].sort_values('img_path'))
# Out:
#                                  img_path  true_SOD_M BP_of_true_SOD_M
# 533   /anau_img3/a49/a4901205.27.icon.JPG           2             head
# 2982  /anau_img3/a49/a4901205.27.icon.JPG           2             head
# 807   /anau_img3/c00/c0000913.04.icon.JPG           3             head
# 3245  /anau_img3/c00/c0000913.04.icon.JPG           4             head
# 1054  /anau_img3/fc0/fc010405.36.icon.JPG           2             head
# 3857  /anau_img3/fc0/fc010405.36.icon.JPG           2             head
# 1259  /anau_img3/fc0/fc010405.50.icon.JPG           2             head
# 3859  /anau_img3/fc0/fc010405.50.icon.JPG           2             head
# 771   /anau_img3/ff1/ff101022.07.icon.JPG           2             head
# 3907  /anau_img3/ff1/ff101022.07.icon.JPG           2             head

# %%
# analyze duplicate images
display(true_sod_df[true_sod_df.duplicated('img_path', keep=False)])

# drop all duplicates
true_sod_df.drop_duplicates(subset='img_path', keep=False, inplace=True)
print(true_sod_df.shape)
# Out:
#                                  img_path  true_SOD_M BP_of_true_SOD_M
# 533   /anau_img3/a49/a4901205.27.icon.JPG           2             head
# 771   /anau_img3/ff1/ff101022.07.icon.JPG           2             head
# 807   /anau_img3/c00/c0000913.04.icon.JPG           3             head
# 1054  /anau_img3/fc0/fc010405.36.icon.JPG           2             head
# 1259  /anau_img3/fc0/fc010405.50.icon.JPG           2             head
# 2982  /anau_img3/a49/a4901205.27.icon.JPG           2             head
# 3245  /anau_img3/c00/c0000913.04.icon.JPG           4             head
# 3857  /anau_img3/fc0/fc010405.36.icon.JPG           2             head
# 3859  /anau_img3/fc0/fc010405.50.icon.JPG           2             head
# 3907  /anau_img3/ff1/ff101022.07.icon.JPG           2             head
# (8341, 3)

# %%
# check unique bodyparts 
true_sod_df.BP_of_true_SOD_M.unique()
# Out:
# array(['head', 'backside', 'torso', 'arm', 'legs'], dtype=object)

# %%
# create image column from img_path column
true_sod_df['img'] = true_sod_df.img_path.str.split('/', expand=True)[3]
true_sod_df['img'] = true_sod_df['img'].str.replace('.icon','')
display(true_sod_df.head())
# Out:
# <ipython-input-69-6f515cf2cf19>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   true_sod_df['img'] = true_sod_df['img'].str.replace('.icon','')
#                               img_path  true_SOD_M BP_of_true_SOD_M  \
# 0  /anau_img3/4cd/4cd00612.21.icon.JPG           1             head
# 1  /anau_img3/b4b/b4b10107.16.icon.JPG           1             head
# 2  /anau_img3/38e/38e10122.04.icon.JPG           1             head
# 3  /anau_img3/0e4/0e401201.29.icon.JPG           1             head
# 4  /anau_img3/0e4/0e401201.28.icon.JPG           1             head
#
#                img
# 0  4cd00612.21.JPG
# 1  b4b10107.16.JPG
# 2  38e10122.04.JPG
# 3  0e401201.29.JPG
# 4  0e401201.28.JPG

# %%
# check unique number of images
true_sod_df.img.nunique()
# Out:
# 8341

# %%
# left join base_df6 with true_sod_df
base_df7 = pd.merge(base_df6, true_sod_df[['img', 'true_SOD_M', 'BP_of_true_SOD_M']], how='left', on='img')
display(base_df7.head())
display(base_df7.info())
print(base_df7.shape)
del true_sod_df
# Out:
#   new_id    old_id  \
# 0    000  UT01-18D
# 1    000  UT01-18D
# 2    000  UT01-18D
# 3    000  UT01-18D
# 4    000  UT01-18D
#
#                                                              img_path  \
# 0  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.01.JPG
# 1  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.02.JPG
# 2  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.03.JPG
# 3  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.04.JPG
# 4  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.05.JPG
#
#                img correct_img_date date_placed_ARF  PMI_days  year  \
# 0  00000121.01.JPG       2018-01-21      2018-01-21       0.0  2018
# 1  00000121.02.JPG       2018-01-21      2018-01-21       0.0  2018
# 2  00000121.03.JPG       2018-01-21      2018-01-21       0.0  2018
# 3  00000121.04.JPG       2018-01-21      2018-01-21       0.0  2018
# 4  00000121.05.JPG       2018-01-21      2018-01-21       0.0  2018
#
#    age_at_death   race   sex  autopsy  est_weight_lb  est_weight_kg  \
# 0          73.0  white  Male    False          160.0      72.562358
# 1          73.0  white  Male    False          160.0      72.562358
# 2          73.0  white  Male    False          160.0      72.562358
# 3          73.0  white  Male    False          160.0      72.562358
# 4          73.0  white  Male    False          160.0      72.562358
#
#    est_stature_in  est_stature_cm  cadaver_stature_cm  cadaver_weight_lbs  \
# 0            70.0           177.8               169.0               150.0
# 1            70.0           177.8               169.0               150.0
# 2            70.0           177.8               169.0               150.0
# 3            70.0           177.8               169.0               150.0
# 4            70.0           177.8               169.0               150.0
#
#   date_placed_ARF_freezer true_BP   pred_BP  pred_BP_conf true_SOD_G  \
# 0              2018-01-04     NaN     stake        100.00        NaN
# 1              2018-01-04     NaN  fullbody         85.51        NaN
# 2              2018-01-04     NaN  fullbody         90.52        NaN
# 3              2018-01-04     NaN  fullbody         99.50        NaN
# 4              2018-01-04     NaN  fullbody         43.47        NaN
#
#   BP_of_true_SOD_G  pred_SOD_G  pred_SOD_G_conf  true_SOD_M BP_of_true_SOD_M
# 0              NaN         NaN              NaN         NaN              NaN
# 1              NaN         NaN              NaN         NaN              NaN
# 2              NaN         NaN              NaN         NaN              NaN
# 3              NaN         NaN              NaN         NaN              NaN
# 4              NaN         NaN              NaN         NaN              NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1132970 entries, 0 to 1132969
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   new_id                   1132970 non-null  object
#  1   old_id                   1132970 non-null  object
#  2   img_path                 1132970 non-null  object
#  3   img                      1132970 non-null  object
#  4   correct_img_date         1132970 non-null  object
#  5   date_placed_ARF          1132970 non-null  object
#  6   PMI_days                 1132970 non-null  float64
#  7   year                     1132970 non-null  int64
#  8   age_at_death             1124770 non-null  float64
#  9   race                     1132348 non-null  object
#  10  sex                      1132630 non-null  object
#  11  autopsy                  1132970 non-null  bool
#  12  est_weight_lb            1056421 non-null  float64
#  13  est_weight_kg            1056219 non-null  float64
#  14  est_stature_in           1068494 non-null  float64
#  15  est_stature_cm           1068494 non-null  float64
#  16  cadaver_stature_cm       993005 non-null   float64
#  17  cadaver_weight_lbs       1103693 non-null  float64
#  18  date_placed_ARF_freezer  199868 non-null   datetime64[ns]
#  19  true_BP                  45930 non-null    object
#  20  pred_BP                  1132692 non-null  object
#  21  pred_BP_conf             1132692 non-null  float64
#  22  true_SOD_G               6055 non-null     object
#  23  BP_of_true_SOD_G         6055 non-null     object
#  24  pred_SOD_G               20873 non-null    float64
#  25  pred_SOD_G_conf          20873 non-null    float64
#  26  true_SOD_M               6115 non-null     float64
#  27  BP_of_true_SOD_M         6115 non-null     object
# dtypes: bool(1), datetime64[ns](1), float64(12), int64(1), object(13)
# memory usage: 243.1+ MB
# None
# (1132970, 28)

# %% [markdown]
# ### Predicted SOD Megyesi data
# Does not exist because Megyesi SOD models have not been used to predict other images.

# %%
# free up memory 
del base_df, base_df2, base_df3, base_df4, base_df5, base_df6

# %% [markdown]
# # Processing of base_df7 into master_df

# %%
base_df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1132970 entries, 0 to 1132969
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   new_id                   1132970 non-null  object
#  1   old_id                   1132970 non-null  object
#  2   img_path                 1132970 non-null  object
#  3   img                      1132970 non-null  object
#  4   correct_img_date         1132970 non-null  object
#  5   date_placed_ARF          1132970 non-null  object
#  6   PMI_days                 1132970 non-null  float64
#  7   year                     1132970 non-null  int64
#  8   age_at_death             1124770 non-null  float64
#  9   race                     1132348 non-null  object
#  10  sex                      1132630 non-null  object
#  11  autopsy                  1132970 non-null  bool
#  12  est_weight_lb            1056421 non-null  float64
#  13  est_weight_kg            1056219 non-null  float64
#  14  est_stature_in           1068494 non-null  float64
#  15  est_stature_cm           1068494 non-null  float64
#  16  cadaver_stature_cm       993005 non-null   float64
#  17  cadaver_weight_lbs       1103693 non-null  float64
#  18  date_placed_ARF_freezer  199868 non-null   datetime64[ns]
#  19  true_BP                  45930 non-null    object
#  20  pred_BP                  1132692 non-null  object
#  21  pred_BP_conf             1132692 non-null  float64
#  22  true_SOD_G               6055 non-null     object
#  23  BP_of_true_SOD_G         6055 non-null     object
#  24  pred_SOD_G               20873 non-null    float64
#  25  pred_SOD_G_conf          20873 non-null    float64
#  26  true_SOD_M               6115 non-null     float64
#  27  BP_of_true_SOD_M         6115 non-null     object
# dtypes: bool(1), datetime64[ns](1), float64(12), int64(1), object(13)
# memory usage: 243.1+ MB

# %%
base_df7.describe()
# Out:
#            PMI_days          year  age_at_death  est_weight_lb  est_weight_kg  \
# count  1.132970e+06  1.132970e+06  1.124770e+06   1.056421e+06   1.056219e+06
# mean   5.395654e+01  2.015284e+03  6.567032e+01   1.850258e+02   8.388591e+01
# std    7.805390e+01  2.237775e+00  1.502242e+01   6.110956e+01   2.765280e+01
# min    0.000000e+00  2.011000e+03  1.800000e+01   7.500000e+01   3.401361e+01
# 25%    1.600000e+01  2.014000e+03  5.800000e+01   1.410000e+02   6.394558e+01
# 50%    3.600000e+01  2.015000e+03  6.700000e+01   1.750000e+02   7.936508e+01
# 75%    6.700000e+01  2.017000e+03  7.500000e+01   2.120000e+02   9.614512e+01
# max    2.359000e+03  2.022000e+03  9.800000e+01   5.160000e+02   2.340136e+02
#
#        est_stature_in  est_stature_cm  cadaver_stature_cm  cadaver_weight_lbs  \
# count    1.068494e+06    1.068494e+06       993005.000000        1.103693e+06
# mean     6.716768e+01    1.706059e+02          167.391129        1.774046e+02
# std      4.038573e+00    1.025798e+01           13.527696        7.061692e+01
# min      5.050000e+01    1.282700e+02          134.000000        5.700000e+01
# 25%      6.400000e+01    1.625600e+02          160.000000        1.270000e+02
# 50%      6.700000e+01    1.701800e+02          166.500000        1.690000e+02
# 75%      7.000000e+01    1.778000e+02          174.000000        2.110000e+02
# max      8.000000e+01    2.032000e+02          348.000000        5.530000e+02
#
#        pred_BP_conf    pred_SOD_G  pred_SOD_G_conf   true_SOD_M
# count  1.132692e+06  20873.000000     20873.000000  6115.000000
# mean   9.013993e+01      3.448953         0.912515     2.644481
# std    1.611813e+01      1.114769         0.140383     0.972058
# min    1.591000e+01      1.000000         0.302266     1.000000
# 25%    8.705000e+01      3.000000         0.883303     2.000000
# 50%    9.912000e+01      3.000000         0.990769     2.000000
# 75%    9.996000e+01      4.000000         0.999857     4.000000
# max    1.000000e+02      6.000000         1.000000     4.000000

# %%
# analyze BP columns
print(base_df7.true_BP.unique())
print(base_df7.pred_BP.unique())
print(base_df7.BP_of_true_SOD_G.unique())
print(base_df7.BP_of_true_SOD_M.unique())
# Out:
# [nan 'fullbody' 'backside' 'arm' 'foot' 'hips' 'head' 'legs' 'hand' 'back'
#  'other' 'plastic' 'torso' 'stake' 'knee' 'shade']
# ['stake' 'fullbody' 'foot' 'plastic' 'torso' 'legs' 'head' 'arm' 'hand'
#  'backside' nan]
# [nan 'torso' 'legs' 'head' 'arm']
# [nan 'head' 'backside' 'legs' 'arm' 'torso']

# %%
# analyze SOD Gelderman columns
print(base_df7.true_SOD_G.unique())
print(base_df7.pred_SOD_G.unique())
# Out:
# [nan 't-3' 'l-3' 'h-3' 'l-4' 't-2' 't-5' 'h-5' 't-6' 'h-6' 't-4' 'h-4'
#  'h-2' 'l-2' 't-1' 'h-1' 'l-6' 'l-5' 'l-1']
# [nan  2.  3.  4.  6.  5.  1.]

# %%
# convert SOD Gelderman columns to numeric
base_df7['true_SOD_G'] = base_df7['true_SOD_G'].str.extract('(\d+)', expand=False).copy()
base_df7['true_SOD_G'] = base_df7['true_SOD_G'].astype(float)
print(base_df7.true_SOD_G.unique())
base_df7['pred_SOD_G'] = base_df7['pred_SOD_G'].astype(float)
print(base_df7.pred_SOD_G.unique())
print(base_df7.info())
# Out:
# [nan  3.  4.  2.  5.  6.  1.]
# [nan  2.  3.  4.  6.  5.  1.]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1132970 entries, 0 to 1132969
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   new_id                   1132970 non-null  object
#  1   old_id                   1132970 non-null  object
#  2   img_path                 1132970 non-null  object
#  3   img                      1132970 non-null  object
#  4   correct_img_date         1132970 non-null  object
#  5   date_placed_ARF          1132970 non-null  object
#  6   PMI_days                 1132970 non-null  float64
#  7   year                     1132970 non-null  int64
#  8   age_at_death             1124770 non-null  float64
#  9   race                     1132348 non-null  object
#  10  sex                      1132630 non-null  object
#  11  autopsy                  1132970 non-null  bool
#  12  est_weight_lb            1056421 non-null  float64
#  13  est_weight_kg            1056219 non-null  float64
#  14  est_stature_in           1068494 non-null  float64
#  15  est_stature_cm           1068494 non-null  float64
#  16  cadaver_stature_cm       993005 non-null   float64
#  17  cadaver_weight_lbs       1103693 non-null  float64
#  18  date_placed_ARF_freezer  199868 non-null   datetime64[ns]
#  19  true_BP                  45930 non-null    object
#  20  pred_BP                  1132692 non-null  object
#  21  pred_BP_conf             1132692 non-null  float64
#  22  true_SOD_G               6055 non-null     float64
#  23  BP_of_true_SOD_G         6055 non-null     object
#  24  pred_SOD_G               20873 non-null    float64
#  25  pred_SOD_G_conf          20873 non-null    float64
#  26  true_SOD_M               6115 non-null     float64
#  27  BP_of_true_SOD_M         6115 non-null     object
# dtypes: bool(1), datetime64[ns](1), float64(13), int64(1), object(12)
# memory usage: 243.1+ MB
# None

# %%
# analyze SOD Megyesi columns
print(base_df7.true_SOD_M.unique())
# Out:
# [nan  2.  3.  1.  4.]

# %%
base_df7.shape
# Out:
# (1132970, 28)

# %%
# save processed base_df6 as pickle file
base_df7.to_csv('../data/master_dataset.csv')
base_df7.to_pickle('../data/master_dataset.pkl')
