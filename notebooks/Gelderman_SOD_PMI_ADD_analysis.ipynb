# %%
import pandas as pd
import numpy as np
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
import seaborn as sns
import pickle

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', 700)

# %% [markdown]
# # Import data

# %%
with open('./../data/subset_master_dataset_w_weather.pkl', 'rb') as f:
        data_ls = pickle.load(f)
print(len(data_ls))
# Out:
# 5565

# %%
# convert list of dicts to dataframe
data_df = pd.DataFrame.from_dict(data_ls)
print(data_df.shape)
display(data_df.head())
display(data_df.info())
display(data_df.describe())
# Out:
# (5565, 21)
#   new_id    old_id  \
# 0    004  UT06-18D
# 1    004  UT06-18D
# 2    004  UT06-18D
# 3    004  UT06-18D
# 4    004  UT06-18D
#
#                                                              img_path  \
# 0  /da1_data/icputrd/arf/mean.js/public/anau_img3/004/00400124.07.JPG
# 1  /da1_data/icputrd/arf/mean.js/public/anau_img3/004/00400124.10.JPG
# 2  /da1_data/icputrd/arf/mean.js/public/anau_img3/004/00400124.11.JPG
# 3  /da1_data/icputrd/arf/mean.js/public/anau_img3/004/00400124.12.JPG
# 4  /da1_data/icputrd/arf/mean.js/public/anau_img3/004/00400124.13.JPG
#
#                img correct_img_date date_placed_ARF  PMI_days  sex  \
# 0  00400124.07.JPG       2018-01-24      2018-01-09      15.0  0.0
# 1  00400124.10.JPG       2018-01-24      2018-01-09      15.0  0.0
# 2  00400124.11.JPG       2018-01-24      2018-01-09      15.0  0.0
# 3  00400124.12.JPG       2018-01-24      2018-01-09      15.0  0.0
# 4  00400124.13.JPG       2018-01-24      2018-01-09      15.0  0.0
#
# ...

# %% [markdown]
# # Extract head images

# %%
heads_df = data_df[data_df.true_SOD_BP == 'head']
print(heads_df.shape)
display(heads_df.info())
# Out:
# (1834, 21)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1834 entries, 3 to 5563
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   new_id              1834 non-null   object
#  1   old_id              1834 non-null   object
#  2   img_path            1834 non-null   object
#  3   img                 1834 non-null   object
#  4   correct_img_date    1834 non-null   datetime64[ns]
#  5   date_placed_ARF     1834 non-null   datetime64[ns]
#  6   PMI_days            1834 non-null   float64
#  7   sex                 1834 non-null   float64
#  8   age_at_death        1834 non-null   float64
#  9   est_stature_inches  1834 non-null   float64
#  10  est_weight          1834 non-null   float64
#  11  true_SOD            1834 non-null   float64
#  12  true_SOD_BP         1834 non-null   object
#  13  ADD_thres0          1834 non-null   float64
#  14  ADD_thres5          1834 non-null   float64
# ...

# %%
# remove images with pmi > 365 days
heads_df = heads_df[heads_df.PMI_days <= 365].copy()
heads_df.describe()
# Out:
#           PMI_days          sex  age_at_death  est_stature_inches  \
# count  1826.000000  1826.000000   1826.000000         1826.000000
# mean     42.571194     0.478094     66.216320          153.273886
# std      40.534195     0.499657     14.516454           40.387706
# min       0.000000     0.000000     21.000000            0.000000
# 25%      13.000000     0.000000     58.000000          157.480000
# 50%      28.000000     0.000000     68.000000          165.100000
# 75%      58.000000     1.000000     76.000000          175.260000
# max     338.000000     1.000000     96.000000          195.580000
#
#         est_weight     true_SOD   ADD_thres0   ADD_thres5  ADD_thres10  \
# count  1826.000000  1826.000000  1826.000000  1826.000000  1826.000000
# mean    183.353231     3.559693   570.515547   553.044159   499.002507
# std      57.685644     1.166189   655.370345   652.662396   645.370451
# min      95.000000     1.000000     0.735417     0.000000     0.000000
# ...

# %%
sod1_heads_df = heads_df[heads_df.true_SOD == 1]
sod1_heads_df[['ADD_thres0']].describe()
# Out:
#        ADD_thres0
# count   26.000000
# mean    33.985833
# std     43.870974
# min      0.735417
# 25%      8.002083
# 50%     21.301389
# 75%     37.856944
# max    175.521111

# %%
sod2_heads_df = heads_df[heads_df.true_SOD == 2]
sod2_heads_df[['ADD_thres0']].describe()
# Out:
#        ADD_thres0
# count  216.000000
# mean    71.947589
# std     50.345112
# min      0.735417
# 25%     38.173767
# 50%     57.310605
# 75%    107.381875
# max    226.301845

# %%
sod3_heads_df = heads_df[heads_df.true_SOD == 3]
sod3_heads_df[['ADD_thres0']].describe()
# Out:
#         ADD_thres0
# count   847.000000
# mean    407.784707
# std     351.683375
# min      18.664583
# 25%     174.904965
# 50%     294.758681
# 75%     549.162522
# max    4372.935124

# %%
sod4_heads_df = heads_df[heads_df.true_SOD == 4]
sod4_heads_df[['ADD_thres0']].describe()
# Out:
#         ADD_thres0
# count   353.000000
# mean    806.897094
# std     800.671768
# min      45.977282
# 25%     300.734653
# 50%     556.066538
# 75%     972.895227
# max    5635.979608

# %%
sod5_heads_df = heads_df[heads_df.true_SOD == 5]
sod5_heads_df[['ADD_thres0']].describe()
# Out:
#         ADD_thres0
# count   215.000000
# mean    885.142723
# std     643.934321
# min      77.092361
# 25%     377.692049
# 50%     652.340397
# 75%    1206.436840
# max    3155.591477

# %%
sod6_heads_df = heads_df[heads_df.true_SOD == 6]
sod6_heads_df[['ADD_thres0']].describe()
# Out:
#         ADD_thres0
# count   169.000000
# mean   1211.852494
# std    1006.262009
# min     192.799860
# 25%     514.768194
# 50%     762.611920
# 75%    1847.143612
# max    4012.242086
