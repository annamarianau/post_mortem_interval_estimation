# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
import seaborn as sns
import pickle
import math

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', 700)

# %% [markdown]
# This notebook samples the entire decay process for a certain number of donors.

# %% [markdown]
# # Import master dataset and process it

# %%
# import master dataset
master_data = pd.read_pickle('../data/master_dataset.pkl')
print(len(master_data))
display(master_data.head())
# Out:
# 1132970
#   new_id    old_id  \
# 0    000  UT01-18D
# 1    000  UT01-18D
# 2    000  UT01-18D
# 3    000  UT01-18D
# 4    000  UT01-18D
#
#                                                              img_path  \
# 0  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.01.JPG
# 1  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.02.JPG
# 2  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.03.JPG
# 3  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.04.JPG
# 4  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.05.JPG
#
#                img correct_img_date date_placed_ARF  PMI_days    year   sex  \
# 0  00000121.01.JPG       2018-01-21      2018-01-21       0.0  2018.0  Male
# 1  00000121.02.JPG       2018-01-21      2018-01-21       0.0  2018.0  Male
# 2  00000121.03.JPG       2018-01-21      2018-01-21       0.0  2018.0  Male
# 3  00000121.04.JPG       2018-01-21      2018-01-21       0.0  2018.0  Male
# 4  00000121.05.JPG       2018-01-21      2018-01-21       0.0  2018.0  Male
#
#   ancestry  est_stature_cm  est_weight_lb  est_stature_in  age_at_death  \
# 0      NaN           177.8          160.0       70.000038          64.0
# 1      NaN           177.8          160.0       70.000038          64.0
# 2      NaN           177.8          160.0       70.000038          64.0
# 3      NaN           177.8          160.0       70.000038          64.0
# 4      NaN           177.8          160.0       70.000038          64.0
#
#   true_BP   pred_BP  pred_BP_conf  true_SOD_G BP_of_true_SOD_G  pred_SOD_G  \
# 0     NaN     stake        100.00         NaN              NaN         NaN
# 1     NaN  fullbody         85.51         NaN              NaN         NaN
# 2     NaN  fullbody         90.52         NaN              NaN         NaN
# 3     NaN  fullbody         99.50         NaN              NaN         NaN
# 4     NaN  fullbody         43.47         NaN              NaN         NaN
#
#    pred_SOD_G_conf  true_SOD_M BP_of_true_SOD_M
# 0              NaN         NaN              NaN
# 1              NaN         NaN              NaN
# 2              NaN         NaN              NaN
# 3              NaN         NaN              NaN
# 4              NaN         NaN              NaN

# %%
# extract donor_date from img column
master_data['donor_date'] = master_data.img.str.split('.', expand=True)[0]
display(master_data.head(3))
# Out:
#   new_id    old_id  \
# 0    000  UT01-18D
# 1    000  UT01-18D
# 2    000  UT01-18D
#
#                                                              img_path  \
# 0  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.01.JPG
# 1  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.02.JPG
# 2  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.03.JPG
#
#                img correct_img_date date_placed_ARF  PMI_days    year   sex  \
# 0  00000121.01.JPG       2018-01-21      2018-01-21       0.0  2018.0  Male
# 1  00000121.02.JPG       2018-01-21      2018-01-21       0.0  2018.0  Male
# 2  00000121.03.JPG       2018-01-21      2018-01-21       0.0  2018.0  Male
#
#   ancestry  est_stature_cm  est_weight_lb  est_stature_in  age_at_death  \
# 0      NaN           177.8          160.0       70.000038          64.0
# 1      NaN           177.8          160.0       70.000038          64.0
# 2      NaN           177.8          160.0       70.000038          64.0
#
#   true_BP   pred_BP  pred_BP_conf  true_SOD_G BP_of_true_SOD_G  pred_SOD_G  \
# 0     NaN     stake        100.00         NaN              NaN         NaN
# 1     NaN  fullbody         85.51         NaN              NaN         NaN
# 2     NaN  fullbody         90.52         NaN              NaN         NaN
#
#    pred_SOD_G_conf  true_SOD_M BP_of_true_SOD_M donor_date
# 0              NaN         NaN              NaN   00000121
# 1              NaN         NaN              NaN   00000121
# 2              NaN         NaN              NaN   00000121

# %%
# create final_BP column
master_data['final_BP'] = np.where(master_data['true_BP'].notnull(), 
                                            master_data['true_BP'],
                                            master_data['pred_BP'])
display(master_data.head(3))
len(master_data)
# Out:
#   new_id    old_id  \
# 0    000  UT01-18D
# 1    000  UT01-18D
# 2    000  UT01-18D
#
#                                                              img_path  \
# 0  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.01.JPG
# 1  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.02.JPG
# 2  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.03.JPG
#
#                img correct_img_date date_placed_ARF  PMI_days    year   sex  \
# 0  00000121.01.JPG       2018-01-21      2018-01-21       0.0  2018.0  Male
# 1  00000121.02.JPG       2018-01-21      2018-01-21       0.0  2018.0  Male
# 2  00000121.03.JPG       2018-01-21      2018-01-21       0.0  2018.0  Male
#
#   ancestry  est_stature_cm  est_weight_lb  est_stature_in  age_at_death  \
# 0      NaN           177.8          160.0       70.000038          64.0
# 1      NaN           177.8          160.0       70.000038          64.0
# 2      NaN           177.8          160.0       70.000038          64.0
#
#   true_BP   pred_BP  pred_BP_conf  true_SOD_G BP_of_true_SOD_G  pred_SOD_G  \
# 0     NaN     stake        100.00         NaN              NaN         NaN
# 1     NaN  fullbody         85.51         NaN              NaN         NaN
# 2     NaN  fullbody         90.52         NaN              NaN         NaN
#
#    pred_SOD_G_conf  true_SOD_M BP_of_true_SOD_M donor_date  final_BP
# 0              NaN         NaN              NaN   00000121     stake
# 1              NaN         NaN              NaN   00000121  fullbody
# 2              NaN         NaN              NaN   00000121  fullbody
# 1132970

# %%
# remove images where true_BP.isnull() AND pred_BP_conf < 80
master_data_filtered = master_data[(master_data.true_BP.notnull()) | 
                                   ((master_data.true_BP.isnull()) & (master_data.pred_BP_conf >= 80.0))].copy()
display(master_data_filtered.head(3))
len(master_data_filtered)
# Out:
#   new_id    old_id  \
# 0    000  UT01-18D
# 1    000  UT01-18D
# 2    000  UT01-18D
#
#                                                              img_path  \
# 0  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.01.JPG
# 1  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.02.JPG
# 2  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000121.03.JPG
#
#                img correct_img_date date_placed_ARF  PMI_days    year   sex  \
# 0  00000121.01.JPG       2018-01-21      2018-01-21       0.0  2018.0  Male
# 1  00000121.02.JPG       2018-01-21      2018-01-21       0.0  2018.0  Male
# 2  00000121.03.JPG       2018-01-21      2018-01-21       0.0  2018.0  Male
#
#   ancestry  est_stature_cm  est_weight_lb  est_stature_in  age_at_death  \
# 0      NaN           177.8          160.0       70.000038          64.0
# 1      NaN           177.8          160.0       70.000038          64.0
# 2      NaN           177.8          160.0       70.000038          64.0
#
#   true_BP   pred_BP  pred_BP_conf  true_SOD_G BP_of_true_SOD_G  pred_SOD_G  \
# 0     NaN     stake        100.00         NaN              NaN         NaN
# 1     NaN  fullbody         85.51         NaN              NaN         NaN
# 2     NaN  fullbody         90.52         NaN              NaN         NaN
#
#    pred_SOD_G_conf  true_SOD_M BP_of_true_SOD_M donor_date  final_BP
# 0              NaN         NaN              NaN   00000121     stake
# 1              NaN         NaN              NaN   00000121  fullbody
# 2              NaN         NaN              NaN   00000121  fullbody
# 912242

# %%
# keep only where final_BP = head, torso, or  limbs imgs
BP_ls = ['head', 'torso', 'backside', 'arm', 'legs']
master_data_filtered = master_data_filtered[(master_data_filtered.final_BP.isin(BP_ls))].copy()
print(len(master_data_filtered))
print(master_data_filtered.final_BP.unique())
display(master_data_filtered.head())
# Out:
# 538485
# ['torso' 'head' 'arm' 'legs' 'backside']
#    new_id    old_id  \
# 12    000  UT01-18D
# 13    000  UT01-18D
# 15    000  UT01-18D
# 16    000  UT01-18D
# 17    000  UT01-18D
#
#                                                               img_path  \
# 12  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000122.04.JPG
# 13  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000122.05.JPG
# 15  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000122.07.JPG
# 16  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000122.08.JPG
# 17  /da1_data/icputrd/arf/mean.js/public/anau_img3/000/00000122.09.JPG
#
#                 img correct_img_date date_placed_ARF  PMI_days    year   sex  \
# 12  00000122.04.JPG       2018-01-22      2018-01-21       1.0  2018.0  Male
# 13  00000122.05.JPG       2018-01-22      2018-01-21       1.0  2018.0  Male
# 15  00000122.07.JPG       2018-01-22      2018-01-21       1.0  2018.0  Male
# 16  00000122.08.JPG       2018-01-22      2018-01-21       1.0  2018.0  Male
# 17  00000122.09.JPG       2018-01-22      2018-01-21       1.0  2018.0  Male
#
#    ancestry  est_stature_cm  est_weight_lb  est_stature_in  age_at_death  \
# 12      NaN           177.8          160.0       70.000038          64.0
# 13      NaN           177.8          160.0       70.000038          64.0
# 15      NaN           177.8          160.0       70.000038          64.0
# 16      NaN           177.8          160.0       70.000038          64.0
# 17      NaN           177.8          160.0       70.000038          64.0
#
#    true_BP pred_BP  pred_BP_conf  true_SOD_G BP_of_true_SOD_G  pred_SOD_G  \
# 12     NaN   torso         94.74         NaN              NaN         NaN
# 13     NaN   torso         99.77         NaN              NaN         NaN
# 15     NaN    head        100.00         NaN              NaN         NaN
# 16     NaN    head        100.00         NaN              NaN         NaN
# 17     NaN     arm         99.74         NaN              NaN         NaN
#
#     pred_SOD_G_conf  true_SOD_M BP_of_true_SOD_M donor_date final_BP
# 12              NaN         NaN              NaN   00000122    torso
# 13              NaN         NaN              NaN   00000122    torso
# 15              NaN         NaN              NaN   00000122     head
# 16              NaN         2.0             head   00000122     head
# 17              NaN         NaN              NaN   00000122      arm

# %%
# split into individual bodypart dataframes
head_df = master_data_filtered[master_data_filtered.final_BP == 'head'].copy()
torso_df = master_data_filtered[(master_data_filtered.final_BP == 'torso') | (master_data_filtered.final_BP == 'backside')].copy()
limbs_df = master_data_filtered[(master_data_filtered.final_BP == 'arm') | (master_data_filtered.final_BP == 'legs')].copy()
print(head_df.shape, torso_df.shape, limbs_df.shape)
# Out:
# (126582, 25) (148215, 25) (263688, 25)

# %%
# check bodypart dataframes don't contain duplicate images
print(head_df.img.nunique())
print(torso_df.img.nunique())
print(limbs_df.img.nunique())
# Out:
# 126582
# 148215
# 263688

# %%
# align dataframes on donor_date column
head_torso_aligned = pd.merge(head_df , torso_df[['donor_date', 'img','true_SOD_G']], 
                            how='inner', on='donor_date', suffixes= ('_head', '_torso'))
print(head_torso_aligned.shape)
#display(head_torso_aligned.head())

head_torso_limbs_aligned = pd.merge(head_torso_aligned, limbs_df[['donor_date', 'img','true_SOD_G']], 
                                  how='inner', on='donor_date')
print(head_torso_limbs_aligned.shape)
# Out:
# (801203, 27)
# (8637899, 29)

# %%
# rename some columns
head_torso_limbs_aligned.rename(columns={"img": "img_limbs", "true_SOD_G": "true_SOD_G_limbs"}, inplace=True)

# %%
head_torso_limbs_aligned[['img_head', 'img_torso', 'img_limbs']].head()
# Out:
#           img_head        img_torso        img_limbs
# 0  00000122.07.JPG  00000122.04.JPG  00000122.09.JPG
# 1  00000122.07.JPG  00000122.04.JPG  00000122.20.JPG
# 2  00000122.07.JPG  00000122.05.JPG  00000122.09.JPG
# 3  00000122.07.JPG  00000122.05.JPG  00000122.20.JPG
# 4  00000122.07.JPG  00000122.17.JPG  00000122.09.JPG

# %%
head_torso_limbs_aligned.describe()
# Out:
#            PMI_days          year  est_stature_cm  est_weight_lb  \
# count  8.637899e+06  8.606248e+06    7.744076e+06   8.194843e+06
# mean   3.986168e+01  2.014217e+03    1.701235e+02   1.862491e+02
# std    4.610867e+01  1.608117e+00    1.295149e+01   6.265673e+01
# min    0.000000e+00  2.012000e+03    0.000000e+00   7.500000e+01
# 25%    1.200000e+01  2.013000e+03    1.625600e+02   1.440000e+02
# 50%    2.700000e+01  2.014000e+03    1.701800e+02   1.750000e+02
# 75%    5.400000e+01  2.015000e+03    1.778000e+02   2.120000e+02
# max    7.230000e+02  2.022000e+03    1.955800e+02   5.160000e+02
#
#        est_stature_in  age_at_death  pred_BP_conf  true_SOD_G_head  \
# count    8.369531e+06  8.605973e+06  8.637899e+06    128988.000000
# mean     6.675223e+01  6.622147e+01  9.863616e+01         3.479959
# std      5.942957e+00  1.555539e+01  3.721343e+00         1.133239
# min      0.000000e+00  1.800000e+01  2.945000e+01         1.000000
# 25%      6.400003e+01  5.700000e+01  9.953000e+01         3.000000
# 50%      6.700004e+01  6.800000e+01  9.997000e+01         3.000000
# 75%      7.000004e+01  7.700000e+01  1.000000e+02         4.000000
# max      8.000000e+01  9.800000e+01  1.000000e+02         6.000000
#
#           pred_SOD_G  pred_SOD_G_conf     true_SOD_M  true_SOD_G_torso  \
# count  486013.000000    486013.000000  194755.000000      94893.000000
# mean        3.625821         0.923065       2.557413          3.261674
# std         1.280777         0.132007       1.022777          1.111323
# min         1.000000         0.324560       1.000000          1.000000
# 25%         3.000000         0.908885       2.000000          3.000000
# 50%         3.000000         0.996367       2.000000          3.000000
# 75%         5.000000         0.999955       4.000000          4.000000
# max         6.000000         1.000000       4.000000          6.000000
#
#        true_SOD_G_limbs
# count      45532.000000
# mean           3.461456
# std            1.076170
# min            1.000000
# 25%            3.000000
# 50%            3.000000
# 75%            4.000000
# max            6.000000

# %%
del master_data, master_data_filtered

# %% [markdown]
# # Sample data
# Aim is to fill in time gaps of existing Gelderman SOD cohort in order to have some donor labels from fresh to skeletonized.

# %%
# filter such that 0<=PMI_days<=365
img_trips = head_torso_limbs_aligned[head_torso_limbs_aligned.PMI_days <= 365.0].copy()
len(img_trips)
# Out:
# 8595272

# %%
img_trips.dropna(subset=['sex', 'est_weight_lb', 'est_stature_in', 'age_at_death'], inplace=True)
img_trips.shape
# Out:
# (8121248, 29)

# %%
# import Gelderman SOD cohort
g_data = pd.read_csv('../data/Gelderman_SOD_cohort/unique_img_triplets_plus.csv')
print(g_data.shape)
display(g_data.head())
# Out:
# (256, 15)
#   new_id donor_date correct_img_date date_placed_ARF  PMI_days  age_at_death  \
# 0    004   00400124       2018-01-24      2018-01-09      15.0          77.0
# 2    00b   00b00525       2016-05-25      2016-03-07      79.0          38.0
# 3    00b   00b00818       2016-08-18      2016-03-07     164.0          38.0
# 4    00d   00d10116       2019-01-16      2018-11-27      50.0          73.0
# 5    011   01101210       2018-12-10      2018-11-29      11.0          90.0
#
#       sex  est_weight_lb  est_stature_in         img_head  true_SOD_G_head  \
# 0  Female          180.0       64.000000  00400124.12.JPG              3.0
# 2    Male          516.0       73.000039  00b00525.08.JPG              5.0
# 3    Male          516.0       73.000039  00b00818.07.JPG              6.0
# 4    Male          235.0       73.000039  00d10116.07.JPG              5.0
# 5  Female          170.0       69.000037  01101210.06.JPG              2.0
#
#          img_torso  true_SOD_G_torso        img_limbs  true_SOD_G_limbs
# 0  00400124.07.JPG               3.0  00400124.10.JPG               3.0
# 2  00b00525.04.JPG               5.0  00b00525.27.JPG               3.0
# 3  00b00818.05.JPG               6.0  00b00818.11.JPG               3.0
# 4  00d10116.04.JPG               4.0  00d10116.06.JPG               4.0
# 5  01101210.03.JPG               2.0  01101210.08.JPG               2.0

# %%
# extract only donors from g_data
img_trips_filtered = pd.merge(img_trips , g_data[['new_id']].drop_duplicates(), 
                            how='inner', on='new_id')
img_trips_filtered.shape
# Out:
# (3909488, 29)

# %%
# remove donor_date already in g_data (meaning already labeled)
img_trips_filtered2 = pd.merge(img_trips_filtered , g_data[['donor_date']].drop_duplicates(), 
                            how='left', on='donor_date', indicator=True)
print(img_trips_filtered2.shape)
display(img_trips_filtered2.head())

img_trips_filtered2 = img_trips_filtered2[img_trips_filtered2._merge == 'left_only'].copy()
img_trips_filtered2.drop(['_merge'], axis=1, inplace=True)

print(img_trips_filtered2.shape)
display(img_trips_filtered2.head())
# Out:
# (3909488, 30)
#   new_id    old_id  \
# 0    004  UT06-18D
# 1    004  UT06-18D
# 2    004  UT06-18D
# 3    004  UT06-18D
# 4    004  UT06-18D
#
#                                                              img_path  \
# 0  /da1_data/icputrd/arf/mean.js/public/anau_img3/004/00400110.09.JPG
# 1  /da1_data/icputrd/arf/mean.js/public/anau_img3/004/00400110.09.JPG
# 2  /da1_data/icputrd/arf/mean.js/public/anau_img3/004/00400110.09.JPG
# 3  /da1_data/icputrd/arf/mean.js/public/anau_img3/004/00400110.09.JPG
# 4  /da1_data/icputrd/arf/mean.js/public/anau_img3/004/00400110.10.JPG
#
#           img_head correct_img_date date_placed_ARF  PMI_days    year     sex  \
# 0  00400110.09.JPG       2018-01-10      2018-01-09       1.0  2018.0  Female
# 1  00400110.09.JPG       2018-01-10      2018-01-09       1.0  2018.0  Female
# 2  00400110.09.JPG       2018-01-10      2018-01-09       1.0  2018.0  Female
# 3  00400110.09.JPG       2018-01-10      2018-01-09       1.0  2018.0  Female
# 4  00400110.10.JPG       2018-01-10      2018-01-09       1.0  2018.0  Female
#
#   ancestry  est_stature_cm  est_weight_lb  est_stature_in  age_at_death  \
# 0    white             NaN          180.0            64.0          77.0
# 1    white             NaN          180.0            64.0          77.0
# 2    white             NaN          180.0            64.0          77.0
# 3    white             NaN          180.0            64.0          77.0
# 4    white             NaN          180.0            64.0          77.0
#
#   true_BP pred_BP  pred_BP_conf  true_SOD_G_head BP_of_true_SOD_G  pred_SOD_G  \
# 0     NaN    head         98.51              NaN              NaN         NaN
# 1     NaN    head         98.51              NaN              NaN         NaN
# 2     NaN    head         98.51              NaN              NaN         NaN
# 3     NaN    head         98.51              NaN              NaN         NaN
# 4     NaN    head         99.41              NaN              NaN         NaN
#
#    pred_SOD_G_conf  true_SOD_M BP_of_true_SOD_M donor_date final_BP  \
# 0              NaN         1.0             head   00400110     head
# 1              NaN         1.0             head   00400110     head
# 2              NaN         1.0             head   00400110     head
# 3              NaN         1.0             head   00400110     head
# 4              NaN         NaN              NaN   00400110     head
#
#          img_torso  true_SOD_G_torso        img_limbs  true_SOD_G_limbs  \
# 0  00400110.13.JPG               NaN  00400110.11.JPG               NaN
# 1  00400110.13.JPG               NaN  00400110.15.JPG               NaN
# 2  00400110.13.JPG               NaN  00400110.22.JPG               NaN
# 3  00400110.13.JPG               NaN  00400110.26.JPG               NaN
# 4  00400110.13.JPG               NaN  00400110.11.JPG               NaN
#
#       _merge
# 0  left_only
# 1  left_only
# 2  left_only
# 3  left_only
# 4  left_only
# (3827793, 29)
#   new_id    old_id  \
# 0    004  UT06-18D
# 1    004  UT06-18D
# 2    004  UT06-18D
# 3    004  UT06-18D
# 4    004  UT06-18D
#
#                                                              img_path  \
# 0  /da1_data/icputrd/arf/mean.js/public/anau_img3/004/00400110.09.JPG
# 1  /da1_data/icputrd/arf/mean.js/public/anau_img3/004/00400110.09.JPG
# 2  /da1_data/icputrd/arf/mean.js/public/anau_img3/004/00400110.09.JPG
# 3  /da1_data/icputrd/arf/mean.js/public/anau_img3/004/00400110.09.JPG
# 4  /da1_data/icputrd/arf/mean.js/public/anau_img3/004/00400110.10.JPG
#
#           img_head correct_img_date date_placed_ARF  PMI_days    year     sex  \
# 0  00400110.09.JPG       2018-01-10      2018-01-09       1.0  2018.0  Female
# 1  00400110.09.JPG       2018-01-10      2018-01-09       1.0  2018.0  Female
# 2  00400110.09.JPG       2018-01-10      2018-01-09       1.0  2018.0  Female
# 3  00400110.09.JPG       2018-01-10      2018-01-09       1.0  2018.0  Female
# 4  00400110.10.JPG       2018-01-10      2018-01-09       1.0  2018.0  Female
#
#   ancestry  est_stature_cm  est_weight_lb  est_stature_in  age_at_death  \
# 0    white             NaN          180.0            64.0          77.0
# 1    white             NaN          180.0            64.0          77.0
# 2    white             NaN          180.0            64.0          77.0
# 3    white             NaN          180.0            64.0          77.0
# 4    white             NaN          180.0            64.0          77.0
#
#   true_BP pred_BP  pred_BP_conf  true_SOD_G_head BP_of_true_SOD_G  pred_SOD_G  \
# 0     NaN    head         98.51              NaN              NaN         NaN
# 1     NaN    head         98.51              NaN              NaN         NaN
# 2     NaN    head         98.51              NaN              NaN         NaN
# 3     NaN    head         98.51              NaN              NaN         NaN
# 4     NaN    head         99.41              NaN              NaN         NaN
#
#    pred_SOD_G_conf  true_SOD_M BP_of_true_SOD_M donor_date final_BP  \
# 0              NaN         1.0             head   00400110     head
# 1              NaN         1.0             head   00400110     head
# 2              NaN         1.0             head   00400110     head
# 3              NaN         1.0             head   00400110     head
# 4              NaN         NaN              NaN   00400110     head
#
#          img_torso  true_SOD_G_torso        img_limbs  true_SOD_G_limbs
# 0  00400110.13.JPG               NaN  00400110.11.JPG               NaN
# 1  00400110.13.JPG               NaN  00400110.15.JPG               NaN
# 2  00400110.13.JPG               NaN  00400110.22.JPG               NaN
# 3  00400110.13.JPG               NaN  00400110.26.JPG               NaN
# 4  00400110.13.JPG               NaN  00400110.11.JPG               NaN

# %% [markdown]
# ### Donor: 5fc
# Female, 56 years, placed in January, 264 days

# %%
donor_5fc = img_trips_filtered2[img_trips_filtered2.new_id == '5fc'].copy()
print(donor_5fc.shape)
display(donor_5fc.head(1))
display(donor_5fc.describe())
# Out:
# (54356, 29)
#         new_id     old_id  \
# 1246433    5fc  UT102-14D
#
#                                                                    img_path  \
# 1246433  /da1_data/icputrd/arf/mean.js/public/anau_img3/5fc/5fc10106.11.JPG
#
#                 img_head correct_img_date date_placed_ARF  PMI_days    year  \
# 1246433  5fc10106.11.JPG       2015-01-06      2015-01-06       0.0  2014.0
#
#             sex ancestry  est_stature_cm  est_weight_lb  est_stature_in  \
# 1246433  Female      NaN           165.1          102.0       65.000035
#
#          age_at_death true_BP pred_BP  pred_BP_conf  true_SOD_G_head  \
# 1246433          56.0     NaN    head          83.7              NaN
#
#         BP_of_true_SOD_G  pred_SOD_G  pred_SOD_G_conf  true_SOD_M  \
# 1246433              NaN         NaN              NaN         1.0
#
#         BP_of_true_SOD_M donor_date final_BP        img_torso  \
# 1246433             head   5fc10106     head  5fc10106.05.JPG
#
#          true_SOD_G_torso        img_limbs  true_SOD_G_limbs
# 1246433               NaN  5fc10106.07.JPG               NaN
#            PMI_days     year  est_stature_cm  est_weight_lb  est_stature_in  \
# count  54356.000000  54356.0    5.435600e+04        54356.0    54356.000000
# mean      84.301383   2014.0    1.651000e+02          102.0       65.000035
# std       37.190231      0.0    2.842197e-14            0.0        0.000000
# min        0.000000   2014.0    1.651000e+02          102.0       65.000035
# 25%       67.000000   2014.0    1.651000e+02          102.0       65.000035
# 50%       89.000000   2014.0    1.651000e+02          102.0       65.000035
# 75%      103.000000   2014.0    1.651000e+02          102.0       65.000035
# max      264.000000   2014.0    1.651000e+02          102.0       65.000035
#
#        age_at_death  pred_BP_conf  true_SOD_G_head   pred_SOD_G  \
# count       54356.0  54356.000000             32.0  2212.000000
# mean           56.0     96.672000              2.0     3.150090
# std             0.0      5.529848              0.0     0.912789
# min            56.0     42.130000              2.0     2.000000
# 25%            56.0     96.090000              2.0     2.000000
# 50%            56.0     99.300000              2.0     4.000000
# 75%            56.0     99.870000              2.0     4.000000
# max            56.0    100.000000              2.0     4.000000
#
#        pred_SOD_G_conf   true_SOD_M  true_SOD_G_torso  true_SOD_G_limbs
# count      2212.000000  1277.000000              64.0               0.0
# mean          0.940803     1.779953               3.0               NaN
# std           0.066711     0.524604               0.0               NaN
# min           0.816782     1.000000               3.0               NaN
# 25%           0.880035     1.000000               3.0               NaN
# 50%           0.961953     2.000000               3.0               NaN
# 75%           0.997878     2.000000               3.0               NaN
# max           0.999833     3.000000               3.0               NaN

# %%
donor_5fc_samples = donor_5fc.groupby('PMI_days').sample(1, random_state=1).copy()
donor_5fc_samples = donor_5fc_samples[donor_5fc_samples.PMI_days % 2==0].copy()
donor_5fc_samples.shape
# Out:
# (70, 29)

# %% [markdown]
# ### Donor: 47d
# Male, 63 years, placed in July, 81 days

# %%
donor_47d = img_trips_filtered2[img_trips_filtered2.new_id == '47d'].copy()
print(donor_47d.shape)
display(donor_47d.head(1))
display(donor_47d.describe())
# Out:
# (17161, 29)
#         new_id    old_id  \
# 1017986    47d  UT06-12D
#
#                                                                    img_path  \
# 1017986  /da1_data/icputrd/arf/mean.js/public/anau_img3/47d/47d00716.26.JPG
#
#                 img_head correct_img_date date_placed_ARF  PMI_days    year  \
# 1017986  47d00716.26.JPG       2012-07-16      2012-07-16       0.0  2012.0
#
#           sex ancestry  est_stature_cm  est_weight_lb  est_stature_in  \
# 1017986  Male      NaN          180.34          220.0       71.000038
#
#          age_at_death true_BP pred_BP  pred_BP_conf  true_SOD_G_head  \
# 1017986          63.0     NaN    head         99.99              NaN
#
#         BP_of_true_SOD_G  pred_SOD_G  pred_SOD_G_conf  true_SOD_M  \
# 1017986              NaN         NaN              NaN         NaN
#
#         BP_of_true_SOD_M donor_date final_BP        img_torso  \
# 1017986              NaN   47d00716     head  47d00716.04.JPG
#
#          true_SOD_G_torso        img_limbs  true_SOD_G_limbs
# 1017986               NaN  47d00716.08.JPG               NaN
#            PMI_days     year  est_stature_cm  est_weight_lb  est_stature_in  \
# count  17161.000000  17161.0        17161.00        17161.0    1.716100e+04
# mean      11.471826   2012.0          180.34          220.0    7.100004e+01
# std       11.986007      0.0            0.00            0.0    2.842254e-14
# min        0.000000   2012.0          180.34          220.0    7.100004e+01
# 25%        3.000000   2012.0          180.34          220.0    7.100004e+01
# 50%        6.000000   2012.0          180.34          220.0    7.100004e+01
# 75%       16.000000   2012.0          180.34          220.0    7.100004e+01
# max       81.000000   2012.0          180.34          220.0    7.100004e+01
#
#        age_at_death  pred_BP_conf  true_SOD_G_head  pred_SOD_G  \
# count       17161.0  17161.000000              0.0        80.0
# mean           63.0     98.527530              NaN         3.0
# std             0.0      3.749998              NaN         0.0
# min            63.0     80.590000              NaN         3.0
# 25%            63.0     99.410000              NaN         3.0
# 50%            63.0     99.970000              NaN         3.0
# 75%            63.0    100.000000              NaN         3.0
# max            63.0    100.000000              NaN         3.0
#
#        pred_SOD_G_conf  true_SOD_M  true_SOD_G_torso  true_SOD_G_limbs
# count             80.0  267.000000               0.0               0.0
# mean               1.0    3.629213               NaN               NaN
# std                0.0    0.483922               NaN               NaN
# min                1.0    3.000000               NaN               NaN
# 25%                1.0    3.000000               NaN               NaN
# 50%                1.0    4.000000               NaN               NaN
# 75%                1.0    4.000000               NaN               NaN
# max                1.0    4.000000               NaN               NaN

# %%
donor_47d_samples = donor_47d.groupby('PMI_days').sample(1, random_state=1).copy()
donor_47d_samples = donor_47d_samples[donor_47d_samples.PMI_days % 2==0].copy()
donor_47d_samples.shape
# Out:
# (20, 29)

# %% [markdown]
# ### Donor: 0f2
# Male, 37 years, placed in December, 189 days

# %%
donor_0f2 = img_trips_filtered2[img_trips_filtered2.new_id == '0f2'].copy()
print(donor_0f2.shape)
display(donor_0f2.head(1))
display(donor_0f2.describe())
# Out:
# (114524, 29)
#        new_id    old_id  \
# 352774    0f2  UT79-13D
#
#                                                                   img_path  \
# 352774  /da1_data/icputrd/arf/mean.js/public/anau_img3/0f2/0f201219.35.JPG
#
#                img_head correct_img_date date_placed_ARF  PMI_days    year  \
# 352774  0f201219.35.JPG       2013-12-19      2013-12-19       0.0  2013.0
#
#          sex ancestry  est_stature_cm  est_weight_lb  est_stature_in  \
# 352774  Male      NaN           177.8          200.0       70.000038
#
#         age_at_death true_BP pred_BP  pred_BP_conf  true_SOD_G_head  \
# 352774          37.0     NaN    head         100.0              NaN
#
#        BP_of_true_SOD_G  pred_SOD_G  pred_SOD_G_conf  true_SOD_M  \
# 352774              NaN         NaN              NaN         NaN
#
#        BP_of_true_SOD_M donor_date final_BP        img_torso  \
# 352774              NaN   0f201219     head  0f201219.09.JPG
#
#         true_SOD_G_torso        img_limbs  true_SOD_G_limbs
# 352774               NaN  0f201219.13.JPG               NaN
#             PMI_days      year  est_stature_cm  est_weight_lb  est_stature_in  \
# count  114524.000000  114524.0    1.145240e+05       114524.0    1.145240e+05
# mean       68.419275    2013.0    1.778000e+02          200.0    7.000004e+01
# std        43.223044       0.0    2.842183e-14            0.0    2.842183e-14
# min         0.000000    2013.0    1.778000e+02          200.0    7.000004e+01
# 25%        30.000000    2013.0    1.778000e+02          200.0    7.000004e+01
# 50%        69.000000    2013.0    1.778000e+02          200.0    7.000004e+01
# 75%        99.000000    2013.0    1.778000e+02          200.0    7.000004e+01
# max       189.000000    2013.0    1.778000e+02          200.0    7.000004e+01
#
#        age_at_death   pred_BP_conf  true_SOD_G_head    pred_SOD_G  \
# count      114524.0  114524.000000      4120.000000  24270.000000
# mean           37.0      98.771134         3.528155      3.137412
# std             0.0       3.851984         0.499267      0.406321
# min            37.0      50.160000         3.000000      2.000000
# 25%            37.0      99.590000         3.000000      3.000000
# 50%            37.0      99.960000         4.000000      3.000000
# 75%            37.0     100.000000         4.000000      3.000000
# max            37.0     100.000000         4.000000      5.000000
#
#        pred_SOD_G_conf  true_SOD_M  true_SOD_G_torso  true_SOD_G_limbs
# count     24270.000000  751.000000       3184.000000               0.0
# mean          0.958697    2.597870          3.336683               NaN
# std           0.100646    1.005688          0.941766               NaN
# min           0.505819    1.000000          2.000000               NaN
# 25%           0.990356    2.000000          2.000000               NaN
# 50%           0.999923    3.000000          4.000000               NaN
# 75%           0.999997    3.000000          4.000000               NaN
# max           1.000000    4.000000          4.000000               NaN

# %%
donor_0f2_samples = donor_0f2.groupby('PMI_days').sample(1, random_state=1).copy()
donor_0f2_samples = donor_0f2_samples[donor_0f2_samples.PMI_days % 2==0].copy()
donor_0f2_samples.shape
# Out:
# (76, 29)

# %% [markdown]
# ### Donor: 3e1
# Female, 52 years, placed in October, 61 days

# %%
donor_3e1 = img_trips_filtered2[img_trips_filtered2.new_id == '3e1'].copy()
print(donor_3e1.shape)
display(donor_3e1.head(1))
display(donor_3e1.describe())
# Out:
# (17105, 29)
#        new_id    old_id  \
# 893562    3e1  UT72-12D
#
#                                                                   img_path  \
# 893562  /da1_data/icputrd/arf/mean.js/public/anau_img3/3e1/3e101003.21.JPG
#
#                img_head correct_img_date date_placed_ARF  PMI_days    year  \
# 893562  3e101003.21.JPG       2012-10-03      2012-10-03       0.0  2012.0
#
#            sex ancestry  est_stature_cm  est_weight_lb  est_stature_in  \
# 893562  Female      NaN          182.88          145.0       72.000039
#
#         age_at_death true_BP pred_BP  pred_BP_conf  true_SOD_G_head  \
# 893562          52.0     NaN    head         98.95              NaN
#
#        BP_of_true_SOD_G  pred_SOD_G  pred_SOD_G_conf  true_SOD_M  \
# 893562              NaN         NaN              NaN         NaN
#
#        BP_of_true_SOD_M donor_date final_BP        img_torso  \
# 893562              NaN   3e101003     head  3e101003.04.JPG
#
#         true_SOD_G_torso        img_limbs  true_SOD_G_limbs
# 893562               NaN  3e101003.08.JPG               NaN
#            PMI_days     year  est_stature_cm  est_weight_lb  est_stature_in  \
# count  17105.000000  17105.0    1.710500e+04        17105.0    1.710500e+04
# mean      17.342005   2012.0    1.828800e+02          145.0    7.200004e+01
# std       14.175111      0.0    5.684508e-14            0.0    1.421127e-14
# min        0.000000   2012.0    1.828800e+02          145.0    7.200004e+01
# 25%        9.000000   2012.0    1.828800e+02          145.0    7.200004e+01
# 50%       14.000000   2012.0    1.828800e+02          145.0    7.200004e+01
# 75%       21.000000   2012.0    1.828800e+02          145.0    7.200004e+01
# max       61.000000   2012.0    1.828800e+02          145.0    7.200004e+01
#
#        age_at_death  pred_BP_conf  true_SOD_G_head   pred_SOD_G  \
# count       17105.0  17105.000000              0.0  2508.000000
# mean           52.0     99.213811              NaN     3.198565
# std             0.0      2.593105              NaN     0.668129
# min            52.0     80.550000              NaN     3.000000
# 25%            52.0     99.830000              NaN     3.000000
# 50%            52.0     99.980000              NaN     3.000000
# 75%            52.0    100.000000              NaN     3.000000
# max            52.0    100.000000              NaN     6.000000
#
#        pred_SOD_G_conf  true_SOD_M  true_SOD_G_torso  true_SOD_G_limbs
# count      2508.000000  536.000000               0.0               0.0
# mean          0.904189    2.447761               NaN               NaN
# std           0.148282    0.820915               NaN               NaN
# min           0.406280    2.000000               NaN               NaN
# 25%           0.870332    2.000000               NaN               NaN
# 50%           0.989212    2.000000               NaN               NaN
# 75%           0.999690    2.000000               NaN               NaN
# max           0.999997    4.000000               NaN               NaN

# %%
donor_3e1_samples = donor_3e1.groupby('PMI_days').sample(1, random_state=1).copy()
donor_3e1_samples = donor_3e1_samples[donor_3e1_samples.PMI_days % 2==0].copy()
donor_3e1_samples.shape
# Out:
# (21, 29)

# %% [markdown]
# ### Donor: 2a3
# Male, 47 years, placed in March, 156 days

# %%
donor_2a3 = img_trips_filtered2[img_trips_filtered2.new_id == '2a3'].copy()
print(donor_2a3.shape)
display(donor_2a3.head(1))
display(donor_2a3.describe())
# Out:
# (20388, 29)
#        new_id    old_id  \
# 838046    2a3  UT09-13D
#
#                                                                   img_path  \
# 838046  /da1_data/icputrd/arf/mean.js/public/anau_img3/2a3/2a300309.14.JPG
#
#                img_head correct_img_date date_placed_ARF  PMI_days    year  \
# 838046  2a300309.14.JPG       2013-03-09      2013-03-09       0.0  2013.0
#
#          sex ancestry  est_stature_cm  est_weight_lb  est_stature_in  \
# 838046  Male      NaN           190.5          235.0       75.000041
#
#         age_at_death true_BP pred_BP  pred_BP_conf  true_SOD_G_head  \
# 838046          47.0     NaN    head         100.0              NaN
#
#        BP_of_true_SOD_G  pred_SOD_G  pred_SOD_G_conf  true_SOD_M  \
# 838046              NaN         NaN              NaN         NaN
#
#        BP_of_true_SOD_M donor_date final_BP        img_torso  \
# 838046              NaN   2a300309     head  2a300309.04.JPG
#
#         true_SOD_G_torso        img_limbs  true_SOD_G_limbs
# 838046               NaN  2a300309.08.JPG               NaN
#            PMI_days     year  est_stature_cm  est_weight_lb  est_stature_in  \
# count  20388.000000  20388.0         20388.0        20388.0    2.038800e+04
# mean      43.851383   2013.0           190.5          235.0    7.500004e+01
# std       40.289666      0.0             0.0            0.0    2.842241e-14
# min        0.000000   2013.0           190.5          235.0    7.500004e+01
# 25%       12.000000   2013.0           190.5          235.0    7.500004e+01
# 50%       29.000000   2013.0           190.5          235.0    7.500004e+01
# 75%       68.000000   2013.0           190.5          235.0    7.500004e+01
# max      156.000000   2013.0           190.5          235.0    7.500004e+01
#
#        age_at_death  pred_BP_conf  true_SOD_G_head   pred_SOD_G  \
# count       20388.0  20388.000000              0.0  1726.000000
# mean           47.0     99.081024              NaN     4.590962
# std             0.0      2.990823              NaN     0.491799
# min            47.0     80.370000              NaN     4.000000
# 25%            47.0     99.910000              NaN     4.000000
# 50%            47.0    100.000000              NaN     5.000000
# 75%            47.0    100.000000              NaN     5.000000
# max            47.0    100.000000              NaN     5.000000
#
#        pred_SOD_G_conf  true_SOD_M  true_SOD_G_torso  true_SOD_G_limbs
# count      1726.000000  312.000000               0.0               0.0
# mean          0.862516    2.692308               NaN               NaN
# std           0.143682    0.462280               NaN               NaN
# min           0.590265    2.000000               NaN               NaN
# 25%           0.755225    2.000000               NaN               NaN
# 50%           0.947133    3.000000               NaN               NaN
# 75%           0.988590    3.000000               NaN               NaN
# max           0.999823    3.000000               NaN               NaN

# %%
donor_2a3_samples = donor_2a3.groupby('PMI_days').sample(1, random_state=1).copy()
donor_2a3_samples = donor_2a3_samples[donor_2a3_samples.PMI_days % 2==0].copy()
donor_2a3_samples.shape
# Out:
# (40, 29)

# %% [markdown]
# ## Process new samples

# %%
df_ls = [donor_0f2_samples, donor_2a3_samples, donor_3e1_samples, donor_47d_samples, donor_5fc_samples]

# %%
# concat new sample into a single df
new_samples = pd.concat(df_ls, axis=0)
new_samples.shape
# Out:
# (227, 29)

# %%
# drop duplicates rows 
new_samples.drop_duplicates(inplace=True)
len(new_samples)
# Out:
# 227

# %%
# save as CSV file
#new_samples.to_csv('../data/Gelderman_SOD_cohort/new_samples.csv', index_label=False)

# %%
new_samples.describe()
# Out:
#          PMI_days         year  est_stature_cm  est_weight_lb  est_stature_in  \
# count  227.000000   227.000000      227.000000     227.000000      227.000000
# mean    68.819383  2013.127753      176.815330     172.621145       69.612372
# std     52.755388     0.689026        8.972123      52.488744        3.532334
# min      0.000000  2012.000000      165.100000     102.000000       65.000035
# 25%     24.000000  2013.000000      165.100000     102.000000       65.000035
# 50%     60.000000  2013.000000      177.800000     200.000000       70.000038
# 75%    105.000000  2014.000000      182.880000     220.000000       72.000039
# max    264.000000  2014.000000      190.500000     235.000000       75.000041
#
#        age_at_death  pred_BP_conf  true_SOD_G_head  pred_SOD_G  \
# count    227.000000    227.000000         2.000000   29.000000
# mean      48.299559     98.392467         3.000000    3.448276
# std        9.055295      3.542479         1.414214    0.631676
# min       37.000000     79.940000         2.000000    3.000000
# 25%       37.000000     98.745000         2.500000    3.000000
# 50%       47.000000     99.910000         3.000000    3.000000
# 75%       56.000000     99.990000         3.500000    4.000000
# max       63.000000    100.000000         4.000000    5.000000
#
#        pred_SOD_G_conf  true_SOD_M  true_SOD_G_torso  true_SOD_G_limbs
# count        29.000000    4.000000          2.000000               0.0
# mean          0.943479    2.000000          3.500000               NaN
# std           0.116050    1.154701          0.707107               NaN
# min           0.572499    1.000000          3.000000               NaN
# 25%           0.951932    1.000000          3.250000               NaN
# 50%           0.997762    2.000000          3.500000               NaN
# 75%           0.999959    3.000000          3.750000               NaN
# max           1.000000    3.000000          4.000000               NaN

# %% [markdown]
# #### Prepare file for IPCUTRD labeling

# %%
new_head = new_samples[['img_head']].copy()
new_head['BP'] = 'head'
new_head.columns = ['img', 'BP']
display(new_head.head(2))

new_torso = new_samples[['img_torso']].copy()
new_torso['BP'] = 'torso'
new_torso.columns = ['img', 'BP']
display(new_torso.head(2))

new_limbs = new_samples[['img_limbs']].copy()
new_limbs['BP'] = 'limbs'
new_limbs.columns = ['img', 'BP']
display(new_limbs.head(2))

new_samples2 = pd.concat([new_head, new_torso, new_limbs], axis=0)
print(len(new_samples2))

all_new_no_dups = new_samples2.drop_duplicates('img').copy()
print(len(all_new_no_dups))
display(all_new_no_dups.head())
# Out:
#                     img    BP
# 353207  0f201219.39.JPG  head
# 354628  0f201221.37.JPG  head
#                     img     BP
# 353207  0f201219.12.JPG  torso
# 354628  0f201221.27.JPG  torso
#                     img     BP
# 353207  0f201219.14.JPG  limbs
# 354628  0f201221.22.JPG  limbs
# 681
# 681
#                     img    BP
# 353207  0f201219.39.JPG  head
# 354628  0f201221.37.JPG  head
# 357156  0f201223.42.JPG  head
# 358599  0f201225.36.JPG  head
# 360719  0f201227.40.JPG  head

# %%
# create img_path column
all_new_no_dups['img_path'] = '/da1_data/icputrd/arf/mean.js/public/anau_img3/' \
                                + all_new_no_dups['img'].str[:3] + '/' + all_new_no_dups['img'].astype(str)
display(all_new_no_dups.head())
len(all_new_no_dups)
# Out:
#                     img    BP  \
# 353207  0f201219.39.JPG  head
# 354628  0f201221.37.JPG  head
# 357156  0f201223.42.JPG  head
# 358599  0f201225.36.JPG  head
# 360719  0f201227.40.JPG  head
#
#                                                                   img_path
# 353207  /da1_data/icputrd/arf/mean.js/public/anau_img3/0f2/0f201219.39.JPG
# 354628  /da1_data/icputrd/arf/mean.js/public/anau_img3/0f2/0f201221.37.JPG
# 357156  /da1_data/icputrd/arf/mean.js/public/anau_img3/0f2/0f201223.42.JPG
# 358599  /da1_data/icputrd/arf/mean.js/public/anau_img3/0f2/0f201225.36.JPG
# 360719  /da1_data/icputrd/arf/mean.js/public/anau_img3/0f2/0f201227.40.JPG
# 681

# %%
# save to CSV file which will be used to populate ICPUTRd for labeling
all_new_no_dups[['img_path', 'BP']].to_csv('/home/anau/SOD_labeling/for_PMI_estimation/additional_samples2.csv',
                                          header=False, index=False)
