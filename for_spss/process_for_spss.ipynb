# %%
import pandas as pd
import numpy as np
import datetime
import pickle
import matplotlib.pyplot as plt
import math
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', 700)

# %%
# import Gelderman SOD-labeled data
g_data = pd.read_pickle('../data/Gelderman_SOD_cohort/for_pmi_estimation2.pkl')
print(len(g_data))
display(g_data.head())
display(g_data.info())
# Out:
# 256
#   new_id donor_date correct_img_date date_placed_ARF  PMI_days  age_at_death  \
# 0    004   00400124       2018-01-24      2018-01-09      15.0          77.0
# 1    00b   00b00525       2016-05-25      2016-03-07      79.0          38.0
# 2    00b   00b00818       2016-08-18      2016-03-07     164.0          38.0
# 3    00d   00d10116       2019-01-16      2018-11-27      50.0          73.0
# 4    011   01101210       2018-12-10      2018-11-29      11.0          90.0
#
#    est_weight_lb  est_stature_in         img_head  true_SOD_G_head  \
# 0          180.0       64.000000  00400124.12.JPG              3.0
# 1          516.0       73.000039  00b00525.08.JPG              5.0
# 2          516.0       73.000039  00b00818.07.JPG              6.0
# 3          235.0       73.000039  00d10116.07.JPG              5.0
# 4          170.0       69.000037  01101210.06.JPG              2.0
#
#          img_torso  true_SOD_G_torso        img_limbs  true_SOD_G_limbs  \
# ...

# %%
# calculate total decomposition score (TDS)
g_data['TDS'] = g_data['true_SOD_G_head']+g_data['true_SOD_G_torso']+g_data['true_SOD_G_limbs']
g_data.head()
# Out:
#   new_id donor_date correct_img_date date_placed_ARF  PMI_days  age_at_death  \
# 0    004   00400124       2018-01-24      2018-01-09      15.0          77.0
# 1    00b   00b00525       2016-05-25      2016-03-07      79.0          38.0
# 2    00b   00b00818       2016-08-18      2016-03-07     164.0          38.0
# 3    00d   00d10116       2019-01-16      2018-11-27      50.0          73.0
# 4    011   01101210       2018-12-10      2018-11-29      11.0          90.0
#
#    est_weight_lb  est_stature_in         img_head  true_SOD_G_head  \
# 0          180.0       64.000000  00400124.12.JPG              3.0
# 1          516.0       73.000039  00b00525.08.JPG              5.0
# 2          516.0       73.000039  00b00818.07.JPG              6.0
# 3          235.0       73.000039  00d10116.07.JPG              5.0
# 4          170.0       69.000037  01101210.06.JPG              2.0
#
#          img_torso  true_SOD_G_torso        img_limbs  true_SOD_G_limbs  \
# ...

# %%
# natural log transform PMI and ADD
g_data['log_PMI_days'] = np.log(g_data.PMI_days+0.001)
g_data['log_ADD_thres0'] = np.log(g_data.ADD_thres0+0.001)
g_data.head()
# Out:
#   new_id donor_date correct_img_date date_placed_ARF  PMI_days  age_at_death  \
# 0    004   00400124       2018-01-24      2018-01-09      15.0          77.0
# 1    00b   00b00525       2016-05-25      2016-03-07      79.0          38.0
# 2    00b   00b00818       2016-08-18      2016-03-07     164.0          38.0
# 3    00d   00d10116       2019-01-16      2018-11-27      50.0          73.0
# 4    011   01101210       2018-12-10      2018-11-29      11.0          90.0
#
#    est_weight_lb  est_stature_in         img_head  true_SOD_G_head  \
# 0          180.0       64.000000  00400124.12.JPG              3.0
# 1          516.0       73.000039  00b00525.08.JPG              5.0
# 2          516.0       73.000039  00b00818.07.JPG              6.0
# 3          235.0       73.000039  00d10116.07.JPG              5.0
# 4          170.0       69.000037  01101210.06.JPG              2.0
#
#          img_torso  true_SOD_G_torso        img_limbs  true_SOD_G_limbs  \
# ...

# %%
# standardize numeric features
# binary variables do not need to be standardized, 

# numerical features
num_cols = ['true_SOD_G_head', 'true_SOD_G_torso', 'true_SOD_G_limbs', 'age_at_death','est_weight_lb', 
            'est_stature_in', 'temp_1_3_mean', 'hum_1_3_mean', 'temp_4_7_mean',
           'hum_4_7_mean', 'temp_8_21_mean', 'hum_8_21_mean']

# apply standardization on numerical features
for i in num_cols:
    
    # fit on training data column
    scale = StandardScaler().fit(g_data[[i]])
    
    # transform the training data column
    g_data[i+'_stand'] = scale.transform(g_data[[i]])

# %%
g_data.head()
# Out:
#   new_id donor_date correct_img_date date_placed_ARF  PMI_days  age_at_death  \
# 0    004   00400124       2018-01-24      2018-01-09      15.0          77.0
# 1    00b   00b00525       2016-05-25      2016-03-07      79.0          38.0
# 2    00b   00b00818       2016-08-18      2016-03-07     164.0          38.0
# 3    00d   00d10116       2019-01-16      2018-11-27      50.0          73.0
# 4    011   01101210       2018-12-10      2018-11-29      11.0          90.0
#
#    est_weight_lb  est_stature_in         img_head  true_SOD_G_head  \
# 0          180.0       64.000000  00400124.12.JPG              3.0
# 1          516.0       73.000039  00b00525.08.JPG              5.0
# 2          516.0       73.000039  00b00818.07.JPG              6.0
# 3          235.0       73.000039  00d10116.07.JPG              5.0
# 4          170.0       69.000037  01101210.06.JPG              2.0
#
#          img_torso  true_SOD_G_torso        img_limbs  true_SOD_G_limbs  \
# ...

# %%
g_data.to_csv('data.csv', index_label=None)
